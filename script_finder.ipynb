# %%
from moviepy.editor import VideoFileClip

def extract_audio(video_path, audio_path):
    print("extract_audio processing...")
    video = VideoFileClip(video_path)
    audio = video.audio
    audio.write_audiofile(audio_path)

# %%
import whisper

def transcribe_audio(audio_path):
    print("transcribe_audio processing...")
    model = whisper.load_model("base")
    result = model.transcribe(audio_path)
    return result

# %%
# 현재는 대본이 없기 때문에 전적으로 음성 인식결과에서 매칭.
# 만약 대본을 구할 수 있다면, 음성인식 부분에서 parse한 결과를 실제 대본으로 업데이트.

import re

def search_text(transcript, query):
    print("search_text processing...")
    matches = re.finditer(query, transcript, re.IGNORECASE)
    return [match.span() for match in matches]

# %%
def search_text(result, query):
    print("search_text processing...")
    for item in result["segments"]:
        if query in item["text"]:
            return item["start"], item["end"], query
    return None, None, query

# %%
def map_time(result, matches):
    print("mapping time processing...")
    segments = result["segments"]
    time_matches = []
    for match in matches:
        start_time = next(seg["start"] for seg in segments if seg["start"] <= match[0] < seg["end"])
        end_time = next(seg["end"] for seg in reversed(segments) if seg["start"] < match[1] <= seg["end"])
        time_matches.append((start_time, end_time))
    return time_matches

# %%
def print_results(time_matches):
    for start, end in time_matches:
        print(f"대사 발견: {start:.2f}초 - {end:.2f}초")

# %%
video_path = "./assets/Goblin_test.mp4"
audio_path = "./assets/Goblin_test.wav"

target_text = "아프고 그럴 때지"

extract_audio(video_path, audio_path)
# Out:
# extract_audio processing...
# MoviePy - Writing audio in ./assets/Goblin_test.wav
# MoviePy - Done.

# %%
result = transcribe_audio(audio_path)
result
# Out:
# transcribe_audio processing...
# {'text': ' 300살이면 한창 아프고 그럴 때지. 괜찮아. 왜? 다시 사실 하나. 답을 어떻게 위해선 답과 가까운 자에게 다가가야 한다. 뭔 소리야? 야 무슨 짓이야 이게 너 하나야. 역시 너에게 나무것도 보이지 않는군. 그저 따뜻할 때. 아 깜짝짝 아파 아파. 야 대소 어떻게 할 거야? 너 꼭 잘 먹었어. 대소. 이소 어떻게 할 거야? 이소. 아 더워. 더워 더워. 잘라버려야 돼. 소독. 이런면 됐죠? 됐네. 다 됐네 소독이. 이제 괜찮아. 걱정 마. 왜 여기로 와 슈퍼 가주면서. 아 궁금하잖아. 내가 진짜 궁금하잖아 처음 먹어봐. 진짜 진짜 처음이야. 궁금하를 처음 먹는 게 아니라 궁금한 처음 먹는 길을 처음 한 것 같은데. 세상에 역시 일을 생활권 지구천 한부 당시 내. 어떻게 이런 우연이 있을 수 있죠? 뭐해 이런 우연 앞에서. 두 분 인사 안 하세요? 우연이 마주쳐도 인사 안 하기로 해서. 인사 안 하기로 했어? 하하. 두 사람 오늘 전체적으로 노른자와 흰자가 안 내 계란으로 해. 아 공 Brain. 아 공 나물이네. 쫄기. 대가리. 공нако 좋아하잖아. 우리 학교 되게 좋죠. 좋네. 되게 싫은 것들 몇 가지 있었는데요? 또 자장하기 되게 좋은 것도 있었어요. 좋은 건 원래 늦게 찾아오나봐요. 아저씨처럼. 일찍 왔는데 몇 반인지 몰랐어. 말고요. 덕방 삼촌. 어 왔어. 왜 일이야? 회사에서 이상한 사람 만나가지고 마음이 등승하고 해서 급방 삼촌 잘 계시나 해서 한번 왔죠. 근데 급방 삼촌. 어? 삼촌이면 삼촌이지. 삼촌은 왜 급방 삼촌이에요? 그러고 보니 급방 삼촌 언제부터 우리 집에 살았죠? 부동산 계약서 보면 알잖아. 아 근데 왜 술 병원 두 병인가요? 누구 왔어요? 내가 양손에 한 벽씩 주고 맛있는 걸 선호해서. 그럼 소파 뒤에 있는 저 발 뒤꿈치는 뭐예요? 야 이게 소파가 참 예쁘다. 참 주인이 안보기 높아. 마무리가 좋아가지고. 어? 아까 그 이상한 그 시안한 머리 하셨네요? 머리가 잘 됐다 그래. 나는 저자의 친구 이 집에 놀러와. 갈 거야. 갈려던 참이었어. 즐거웠어. 가. 어. 그래. 가. 만한 사람은. 만한 사람은. 상스러운 모습이 반가워요. 뭐지? 출시생의 비밀에 급방 삼촌도 한팬가? 방금 이 팀에서 뭔 소리 안 났어요? 안 났는데. 나는데? 나 쏘요 나 쏘. 안 났어 덕호야. 나 5초로만 동갑게. 아. 문 닦고 가. 이걸 왜 이렇게. 퇴퇴. 나 말 한만. 책상해. 아니 왜 이 했을든지 언제인데 웃이라노. 나 10만 한 말. 고기 사기. 뭐요? 널 내 기억에 그대로 둔 신혜 뜻이 있겠지. 그렇게까지 얘기하지 못해서 골라라고. 마지막 방 볼 수는 수밖에. 옛날 생각해서 금너 하러 뚝딱 안 된다. 고유 번호 있어서 내가 팔지도 못한다고. 골라 저럴거야. 소개팅하기만 해 아주. 고유 유분이 한 대 무슨. 유분이요. 라고 했다. 어디 사나요? 저 스타일 아니시라니까. 이 팀이 적상해 좀 맞아요? 어떻게 내 동의도 없어요? 어떻게 여기저기 딱 다 커밍이 나왔을래요? 아 아패다 아패가 왼쪽으로 지켜라. 왜 줄 아네요? 아니 너 운전하는 거 보니까 진짜 어른된 것 같아. 차선 차선. 핸들 꽉 꽉 줘. 아 다 보고 있어. 아니지 알지. 다 알지 내가 신계속을 해. 정석이 처음 타봐서. 좀 좋아해 줘. 좋아해 줘. 좋아해 줘. 왼쪽 왼쪽. 아 진짜 어디 가는데요? 그 좌회전한테 깜빡이 키라고 깜빡이 항상. 아... 산패인에 7도에서 구도사이가 딱이지. 그 바깥쪽. 아 왜 안 마셔도 치하는 거 같네 나는. 벌써 치하면 어떻게 해. 어이씨. 어이씨. 산쪽까지 왜 이래. 괜찮으세요? 안색이 안 좋으세요. 아 괜찮죠? 오케이. 집 또 얼마 추웠어. 한잔 하시겠어요? 네. 저 집을 맞습니다. 김대표님. 김대표님. 아 진짜 정신들 좀 하자. 삼촌들 너무 굳이해하고 천진 난만 해. 뭐지? 왜 이머리 입에 짝 붙지? 너. 너. 아휴. 아휴. 아휴. 무슨 노래. 이 놈 수 못해요. 이렇게 많은. 사람들 가운데. 너를 만난 건 정말의 운이야. 이렇게 넓은 세상 한 건데 다같이. 그들 만난 건 나 역시 기쁨이야. 이렇게 많은 사람들 가운데.',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 3.18,
#    'text': ' 300살이면 한창 아프고 그럴 때지.',
#    'tokens': [50364,
#     6641,
#     26082,
#     42935,
#     4815,
#     36935,
#     2216,
#     19514,
#     1313,
#     45372,
#     7765,
#     1831,
#     13,
#     50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 1,
#    'seek': 0,
#    'start': 3.98,
#    'end': 4.98,
#    'text': ' 괜찮아.',
#    'tokens': [50563, 45058, 13, 50613],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 2,
#    'seek': 0,
#    'start': 7.68,
#    'end': 10.06,
#    'text': ' 왜? 다시 사실 하나.',
#    'tokens': [50748, 9883, 30, 15463, 14504, 12261, 13, 50867],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 3,
#    'seek': 0,
#    'start': 10.06,
#    'end': 13.92,
#    'text': ' 답을 어떻게 위해선 답과 가까운 자에게 다가가야 한다.',
#    'tokens': [50867,
#     41918,
#     1638,
#     12952,
#     9491,
#     7002,
#     226,
#     254,
#     41918,
#     7097,
#     44913,
#     9996,
#     5650,
#     15989,
#     4279,
#     1453,
#     1453,
#     4248,
#     44005,
#     13,
#     51060],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 4,
#    'seek': 0,
#    'start': 13.92,
#    'end': 15.06,
#    'text': ' 뭔 소리야?',
#    'tokens': [51060, 43972, 21652, 4248, 30, 51117],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 5,
#    'seek': 0,
#    'start': 18.28,
#    'end': 20.98,
#    'text': ' 야 무슨 짓이야 이게 너 하나야.',
#    'tokens': [51278,
#     13450,
#     22712,
#     2334,
#     241,
#     15374,
#     10496,
#     12963,
#     12261,
#     4248,
#     13,
#     51413],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 6,
#    'seek': 0,
#    'start': 20.98,
#    'end': 24.12,
#    'text': ' 역시 너에게 나무것도 보이지 않는군.',
#    'tokens': [51413,
#     34522,
#     12963,
#     15989,
#     12623,
#     18129,
#     47450,
#     6330,
#     25721,
#     34790,
#     24707,
#     13,
#     51570],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 7,
#    'seek': 0,
#    'start': 24.12,
#    'end': 25.400000000000002,
#    'text': ' 그저 따뜻할 때.',
#    'tokens': [51570, 4296, 11738, 15933, 250, 119, 7999, 7765, 13, 51634],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 8,
#    'seek': 0,
#    'start': 25.400000000000002,
#    'end': 27.64,
#    'text': ' 아 깜짝짝 아파 아파.',
#    'tokens': [51634, 2216, 8394, 250, 28624, 28624, 46438, 46438, 13, 51746],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 9,
#    'seek': 2764,
#    'start': 27.84,
#    'end': 29.740000000000002,
#    'text': ' 야 대소 어떻게 할 거야?',
#    'tokens': [50374, 13450, 5971, 12012, 12952, 8981, 15928, 30, 50469],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 10,
#    'seek': 2764,
#    'start': 29.740000000000002,
#    'end': 30.82,
#    'text': ' 너 꼭 잘 먹었어.',
#    'tokens': [50469, 12963, 25881, 6644, 6554, 30562, 13, 50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 11,
#    'seek': 2764,
#    'start': 30.82,
#    'end': 31.62,
#    'text': ' 대소.',
#    'tokens': [50523, 5971, 12012, 13, 50563],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 12,
#    'seek': 2764,
#    'start': 31.62,
#    'end': 32.980000000000004,
#    'text': ' 이소 어떻게 할 거야?',
#    'tokens': [50563, 4329, 228, 234, 12952, 8981, 15928, 30, 50631],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 13,
#    'seek': 2764,
#    'start': 32.980000000000004,
#    'end': 33.9,
#    'text': ' 이소.',
#    'tokens': [50631, 4329, 228, 234, 13, 50677],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 14,
#    'seek': 2764,
#    'start': 33.9,
#    'end': 34.980000000000004,
#    'text': ' 아 더워.',
#    'tokens': [50677, 2216, 6990, 10086, 13, 50731],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 15,
#    'seek': 2764,
#    'start': 34.980000000000004,
#    'end': 35.96,
#    'text': ' 더워 더워.',
#    'tokens': [50731, 6990, 10086, 6990, 10086, 13, 50780],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 16,
#    'seek': 2764,
#    'start': 35.96,
#    'end': 36.980000000000004,
#    'text': ' 잘라버려야 돼.',
#    'tokens': [50780, 24041, 9316, 24410, 5743, 4248, 11080, 13, 50831],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 17,
#    'seek': 2764,
#    'start': 41.120000000000005,
#    'end': 42.120000000000005,
#    'text': ' 소독.',
#    'tokens': [51038, 13062, 19079, 13, 51088],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 18,
#    'seek': 2764,
#    'start': 42.88,
#    'end': 44.120000000000005,
#    'text': ' 이런면 됐죠?',
#    'tokens': [51126, 2892, 253, 2004, 2708, 16718, 5837, 30, 51188],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 19,
#    'seek': 2764,
#    'start': 48.400000000000006,
#    'end': 50.1,
#    'text': ' 됐네.',
#    'tokens': [51402, 16718, 17507, 13, 51487],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 20,
#    'seek': 2764,
#    'start': 51.72,
#    'end': 53.16,
#    'text': ' 다 됐네 소독이.',
#    'tokens': [51568, 4279, 3534, 2998, 5626, 13062, 19079, 1129, 13, 51640],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 21,
#    'seek': 2764,
#    'start': 53.44,
#    'end': 55.0,
#    'text': ' 이제 괜찮아.',
#    'tokens': [51654, 8424, 45058, 13, 51732],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 22,
#    'seek': 2764,
#    'start': 55.0,
#    'end': 56.16,
#    'text': ' 걱정 마.',
#    'tokens': [51732, 45315, 6437, 13, 51790],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 23,
#    'seek': 5616,
#    'start': 57.12,
#    'end': 59.339999999999996,
#    'text': ' 왜 여기로 와 슈퍼 가주면서.',
#    'tokens': [50412,
#     9883,
#     5518,
#     27860,
#     12500,
#     6955,
#     230,
#     41982,
#     4147,
#     21163,
#     9332,
#     13,
#     50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 24,
#    'seek': 5616,
#    'start': 59.339999999999996,
#    'end': 61.419999999999995,
#    'text': ' 아 궁금하잖아.',
#    'tokens': [50523, 2216, 32886, 2240, 17065, 13, 50627],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 25,
#    'seek': 5616,
#    'start': 61.419999999999995,
#    'end': 64.11999999999999,
#    'text': ' 내가 진짜 궁금하잖아 처음 먹어봐.',
#    'tokens': [50627,
#     10474,
#     7106,
#     32886,
#     2240,
#     17065,
#     18736,
#     28428,
#     16808,
#     13,
#     50762],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 26,
#    'seek': 5616,
#    'start': 64.11999999999999,
#    'end': 66.28,
#    'text': ' 진짜 진짜 처음이야.',
#    'tokens': [50762, 7106, 7106, 18736, 15374, 13, 50870],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 27,
#    'seek': 5616,
#    'start': 66.75999999999999,
#    'end': 71.25999999999999,
#    'text': ' 궁금하를 처음 먹는 게 아니라 궁금한 처음 먹는 길을 처음 한 것 같은데.',
#    'tokens': [50894,
#     32886,
#     8037,
#     2429,
#     18736,
#     30616,
#     7845,
#     22948,
#     32886,
#     3049,
#     18736,
#     30616,
#     25222,
#     1638,
#     18736,
#     4815,
#     4431,
#     21864,
#     13,
#     51119],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 28,
#    'seek': 5616,
#    'start': 75.12,
#    'end': 79.82,
#    'text': ' 세상에 역시 일을 생활권 지구천 한부 당시 내.',
#    'tokens': [51312,
#     37990,
#     1517,
#     34522,
#     7682,
#     1638,
#     6439,
#     40602,
#     23605,
#     4704,
#     7675,
#     18906,
#     10737,
#     6301,
#     49559,
#     6918,
#     13,
#     51547],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 29,
#    'seek': 5616,
#    'start': 79.82,
#    'end': 82.06,
#    'text': ' 어떻게 이런 우연이 있을 수 있죠?',
#    'tokens': [51547,
#     12952,
#     8381,
#     14995,
#     11557,
#     1129,
#     18082,
#     4446,
#     34070,
#     30,
#     51659],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 30,
#    'seek': 5616,
#    'start': 83.1,
#    'end': 85.42,
#    'text': ' 뭐해 이런 우연 앞에서.',
#    'tokens': [51711, 7034, 5302, 8381, 14995, 11557, 13727, 4885, 13, 51827],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 31,
#    'seek': 8616,
#    'start': 86.16,
#    'end': 88.58,
#    'text': ' 두 분 인사 안 하세요?',
#    'tokens': [50364, 11915, 15361, 9385, 5727, 4811, 3369, 7046, 30, 50485],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 32,
#    'seek': 8616,
#    'start': 88.58,
#    'end': 91.25999999999999,
#    'text': ' 우연이 마주쳐도 인사 안 하기로 해서.',
#    'tokens': [50485,
#     14995,
#     11557,
#     1129,
#     6437,
#     5836,
#     20688,
#     22983,
#     9385,
#     5727,
#     4811,
#     3369,
#     27860,
#     17705,
#     13,
#     50619],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 33,
#    'seek': 8616,
#    'start': 91.25999999999999,
#    'end': 93.25999999999999,
#    'text': ' 인사 안 하기로 했어?',
#    'tokens': [50619, 9385, 5727, 4811, 3369, 27860, 49528, 30, 50719],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 34,
#    'seek': 8616,
#    'start': 93.25999999999999,
#    'end': 94.25999999999999,
#    'text': ' 하하.',
#    'tokens': [50719, 3369, 2240, 13, 50769],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 35,
#    'seek': 8616,
#    'start': 102.25999999999999,
#    'end': 108.3,
#    'text': ' 두 사람 오늘 전체적으로 노른자와 흰자가 안 내 계란으로 해.',
#    'tokens': [51169,
#     11915,
#     12211,
#     8880,
#     6831,
#     44687,
#     4130,
#     13262,
#     10798,
#     4264,
#     7590,
#     14473,
#     108,
#     22310,
#     4811,
#     6918,
#     3352,
#     2703,
#     18781,
#     4130,
#     11683,
#     13,
#     51471],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 36,
#    'seek': 10830,
#    'start': 108.3,
#    'end': 112.44,
#    'text': ' 아 공 Brain.',
#    'tokens': [50364, 2216, 9273, 29783, 13, 50571],
#    'temperature': 1.0,
#    'avg_logprob': -2.227261013454861,
#    'compression_ratio': 0.9767441860465116,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 37,
#    'seek': 10830,
#    'start': 112.44,
#    'end': 116.84,
#    'text': ' 아 공 나물이네.',
#    'tokens': [50571, 2216, 9273, 12623, 11825, 4250, 5626, 13, 50791],
#    'temperature': 1.0,
#    'avg_logprob': -2.227261013454861,
#    'compression_ratio': 0.9767441860465116,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 38,
#    'seek': 10830,
#    'start': 116.84,
#    'end': 118.78,
#    'text': ' 쫄기.',
#    'tokens': [50791, 37453, 226, 2401, 13, 50888],
#    'temperature': 1.0,
#    'avg_logprob': -2.227261013454861,
#    'compression_ratio': 0.9767441860465116,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 39,
#    'seek': 10830,
#    'start': 118.78,
#    'end': 121.44,
#    'text': ' 대가리.',
#    'tokens': [50888, 5971, 16955, 2250, 13, 51021],
#    'temperature': 1.0,
#    'avg_logprob': -2.227261013454861,
#    'compression_ratio': 0.9767441860465116,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 40,
#    'seek': 10830,
#    'start': 121.44,
#    'end': 126.12,
#    'text': ' 공нако 좋아하잖아.',
#    'tokens': [51021, 9273, 32088, 40344, 17065, 13, 51255],
#    'temperature': 1.0,
#    'avg_logprob': -2.227261013454861,
#    'compression_ratio': 0.9767441860465116,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 41,
#    'seek': 12612,
#    'start': 126.12,
#    'end': 136.12,
#    'text': ' 우리 학교 되게 좋죠.',
#    'tokens': [50364, 8126, 24504, 18084, 14860, 5008, 5837, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.6417301722935268,
#    'compression_ratio': 0.9550561797752809,
#    'no_speech_prob': 0.006873470731079578},
#   {'id': 42,
#    'seek': 12612,
#    'start': 136.12,
#    'end': 142.12,
#    'text': ' 좋네.',
#    'tokens': [50864, 5008, 17507, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.6417301722935268,
#    'compression_ratio': 0.9550561797752809,
#    'no_speech_prob': 0.006873470731079578},
#   {'id': 43,
#    'seek': 12612,
#    'start': 142.12,
#    'end': 153.12,
#    'text': ' 되게 싫은 것들 몇 가지 있었는데요?',
#    'tokens': [51164,
#     14860,
#     33649,
#     2124,
#     4431,
#     14271,
#     23628,
#     26569,
#     15972,
#     14586,
#     30,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.6417301722935268,
#    'compression_ratio': 0.9550561797752809,
#    'no_speech_prob': 0.006873470731079578},
#   {'id': 44,
#    'seek': 15312,
#    'start': 153.12,
#    'end': 164.12,
#    'text': ' 또 자장하기 되게 좋은 것도 있었어요.',
#    'tokens': [50364,
#     7992,
#     5650,
#     4573,
#     22700,
#     14860,
#     16460,
#     25942,
#     15972,
#     4213,
#     13,
#     50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.326098018222385,
#    'compression_ratio': 1.177304964539007,
#    'no_speech_prob': 0.0010810885578393936},
#   {'id': 45,
#    'seek': 15312,
#    'start': 164.12,
#    'end': 167.12,
#    'text': ' 좋은 건 원래 늦게 찾아오나봐요.',
#    'tokens': [50914,
#     16460,
#     13507,
#     25169,
#     7707,
#     99,
#     1810,
#     33219,
#     26969,
#     14886,
#     16808,
#     1495,
#     13,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.326098018222385,
#    'compression_ratio': 1.177304964539007,
#    'no_speech_prob': 0.0010810885578393936},
#   {'id': 46,
#    'seek': 15312,
#    'start': 167.12,
#    'end': 169.12,
#    'text': ' 아저씨처럼.',
#    'tokens': [51064, 2216, 11738, 25416, 19881, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.326098018222385,
#    'compression_ratio': 1.177304964539007,
#    'no_speech_prob': 0.0010810885578393936},
#   {'id': 47,
#    'seek': 15312,
#    'start': 169.12,
#    'end': 173.12,
#    'text': ' 일찍 왔는데 몇 반인지 몰랐어.',
#    'tokens': [51164,
#     7682,
#     5786,
#     235,
#     17766,
#     4189,
#     23628,
#     16396,
#     37194,
#     24833,
#     15876,
#     3103,
#     13,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.326098018222385,
#    'compression_ratio': 1.177304964539007,
#    'no_speech_prob': 0.0010810885578393936},
#   {'id': 48,
#    'seek': 15312,
#    'start': 173.12,
#    'end': 178.12,
#    'text': ' 말고요.',
#    'tokens': [51364, 7058, 12364, 13, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.326098018222385,
#    'compression_ratio': 1.177304964539007,
#    'no_speech_prob': 0.0010810885578393936},
#   {'id': 49,
#    'seek': 17812,
#    'start': 179.12,
#    'end': 188.12,
#    'text': ' 덕방 삼촌.',
#    'tokens': [50414, 5596, 243, 27630, 32391, 15241, 234, 13, 50864],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 50,
#    'seek': 17812,
#    'start': 188.12,
#    'end': 190.12,
#    'text': ' 어 왔어.',
#    'tokens': [50864, 9076, 17766, 3103, 13, 50964],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 51,
#    'seek': 17812,
#    'start': 190.12,
#    'end': 191.12,
#    'text': ' 왜 일이야?',
#    'tokens': [50964, 9883, 7682, 15374, 30, 51014],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 52,
#    'seek': 17812,
#    'start': 191.12,
#    'end': 197.12,
#    'text': ' 회사에서 이상한 사람 만나가지고 마음이 등승하고 해서 급방 삼촌 잘 계시나 해서 한번 왔죠.',
#    'tokens': [51014,
#     22980,
#     5727,
#     4885,
#     20362,
#     3049,
#     12211,
#     38841,
#     19747,
#     20477,
#     1129,
#     15722,
#     30426,
#     7040,
#     17705,
#     44728,
#     27630,
#     32391,
#     15241,
#     234,
#     6644,
#     10603,
#     10426,
#     3404,
#     17705,
#     14463,
#     17766,
#     5837,
#     13,
#     51314],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 53,
#    'seek': 17812,
#    'start': 197.12,
#    'end': 201.12,
#    'text': ' 근데 급방 삼촌.',
#    'tokens': [51314, 9907, 44728, 27630, 32391, 15241, 234, 13, 51514],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 54,
#    'seek': 17812,
#    'start': 201.12,
#    'end': 202.12,
#    'text': ' 어?',
#    'tokens': [51514, 9076, 30, 51564],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 55,
#    'seek': 17812,
#    'start': 202.12,
#    'end': 204.12,
#    'text': ' 삼촌이면 삼촌이지.',
#    'tokens': [51564,
#     32391,
#     15241,
#     234,
#     42935,
#     32391,
#     15241,
#     234,
#     25721,
#     13,
#     51664],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 56,
#    'seek': 17812,
#    'start': 204.12,
#    'end': 207.12,
#    'text': ' 삼촌은 왜 급방 삼촌이에요?',
#    'tokens': [51664,
#     32391,
#     15241,
#     234,
#     2124,
#     9883,
#     44728,
#     27630,
#     32391,
#     15241,
#     234,
#     15099,
#     30,
#     51814],
#    'temperature': 0.4,
#    'avg_logprob': -0.38708802107926255,
#    'compression_ratio': 1.4885057471264367,
#    'no_speech_prob': 0.008429797366261482},
#   {'id': 57,
#    'seek': 20712,
#    'start': 207.12,
#    'end': 213.12,
#    'text': ' 그러고 보니 급방 삼촌 언제부터 우리 집에 살았죠?',
#    'tokens': [50364,
#     14019,
#     1313,
#     6330,
#     1425,
#     44728,
#     27630,
#     32391,
#     15241,
#     234,
#     16738,
#     33893,
#     12130,
#     8126,
#     38380,
#     15482,
#     243,
#     246,
#     5837,
#     30,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.19859666933958559,
#    'compression_ratio': 1.2933333333333332,
#    'no_speech_prob': 1.308164337388007e-05},
#   {'id': 58,
#    'seek': 20712,
#    'start': 213.12,
#    'end': 216.12,
#    'text': ' 부동산 계약서 보면 알잖아.',
#    'tokens': [50664,
#     10201,
#     8309,
#     16551,
#     10603,
#     19970,
#     2393,
#     19443,
#     9457,
#     17065,
#     13,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.19859666933958559,
#    'compression_ratio': 1.2933333333333332,
#    'no_speech_prob': 1.308164337388007e-05},
#   {'id': 59,
#    'seek': 20712,
#    'start': 216.12,
#    'end': 219.12,
#    'text': ' 아 근데 왜 술 병원 두 병인가요?',
#    'tokens': [50814,
#     2216,
#     9907,
#     9883,
#     41986,
#     32245,
#     7573,
#     11915,
#     32245,
#     4215,
#     28517,
#     30,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.19859666933958559,
#    'compression_ratio': 1.2933333333333332,
#    'no_speech_prob': 1.308164337388007e-05},
#   {'id': 60,
#    'seek': 20712,
#    'start': 219.12,
#    'end': 222.12,
#    'text': ' 누구 왔어요?',
#    'tokens': [50964, 36385, 17766, 4213, 30, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.19859666933958559,
#    'compression_ratio': 1.2933333333333332,
#    'no_speech_prob': 1.308164337388007e-05},
#   {'id': 61,
#    'seek': 20712,
#    'start': 222.12,
#    'end': 227.12,
#    'text': ' 내가 양손에 한 벽씩 주고 맛있는 걸 선호해서.',
#    'tokens': [51114,
#     10474,
#     17723,
#     45443,
#     1517,
#     4815,
#     7307,
#     121,
#     24317,
#     45848,
#     49051,
#     14240,
#     11835,
#     14705,
#     8275,
#     13,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.19859666933958559,
#    'compression_ratio': 1.2933333333333332,
#    'no_speech_prob': 1.308164337388007e-05},
#   {'id': 62,
#    'seek': 20712,
#    'start': 227.12,
#    'end': 235.12,
#    'text': ' 그럼 소파 뒤에 있는 저 발 뒤꿈치는 뭐예요?',
#    'tokens': [51364,
#     13929,
#     10614,
#     17974,
#     40856,
#     7153,
#     4841,
#     13825,
#     19798,
#     30484,
#     230,
#     47255,
#     7034,
#     10790,
#     30,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.19859666933958559,
#    'compression_ratio': 1.2933333333333332,
#    'no_speech_prob': 1.308164337388007e-05},
#   {'id': 63,
#    'seek': 23512,
#    'start': 235.12,
#    'end': 238.12,
#    'text': ' 야 이게 소파가 참 예쁘다.',
#    'tokens': [50364,
#     13450,
#     10496,
#     10614,
#     17974,
#     1453,
#     18255,
#     28424,
#     1235,
#     13,
#     50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 64,
#    'seek': 23512,
#    'start': 238.12,
#    'end': 240.12,
#    'text': ' 참 주인이 안보기 높아.',
#    'tokens': [50514,
#     18255,
#     7757,
#     30603,
#     9658,
#     7062,
#     2401,
#     25015,
#     2230,
#     13,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 65,
#    'seek': 23512,
#    'start': 240.12,
#    'end': 241.12,
#    'text': ' 마무리가 좋아가지고.',
#    'tokens': [50614, 43797, 27116, 10805, 19747, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 66,
#    'seek': 23512,
#    'start': 241.12,
#    'end': 242.12,
#    'text': ' 어?',
#    'tokens': [50664, 9076, 30, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 67,
#    'seek': 23512,
#    'start': 242.12,
#    'end': 247.12,
#    'text': ' 아까 그 이상한 그 시안한 머리 하셨네요?',
#    'tokens': [50714,
#     25289,
#     4296,
#     20362,
#     3049,
#     4296,
#     5710,
#     11264,
#     3049,
#     27089,
#     3369,
#     44861,
#     12974,
#     30,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 68,
#    'seek': 23512,
#    'start': 247.12,
#    'end': 248.12,
#    'text': ' 머리가 잘 됐다 그래.',
#    'tokens': [50964, 27089, 1453, 6644, 16718, 1235, 7080, 13, 51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 69,
#    'seek': 23512,
#    'start': 248.12,
#    'end': 250.12,
#    'text': ' 나는 저자의 친구 이 집에 놀러와.',
#    'tokens': [51014,
#     17955,
#     4841,
#     4264,
#     2785,
#     28307,
#     2620,
#     38380,
#     29873,
#     6235,
#     7590,
#     13,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 70,
#    'seek': 23512,
#    'start': 250.12,
#    'end': 251.12,
#    'text': ' 갈 거야.',
#    'tokens': [51114, 23616, 15928, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 71,
#    'seek': 23512,
#    'start': 251.12,
#    'end': 253.12,
#    'text': ' 갈려던 참이었어.',
#    'tokens': [51164, 1777, 2196, 19479, 8092, 18255, 25569, 3103, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 72,
#    'seek': 23512,
#    'start': 253.12,
#    'end': 255.12,
#    'text': ' 즐거웠어.',
#    'tokens': [51264, 35177, 4285, 36450, 3103, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 73,
#    'seek': 23512,
#    'start': 255.12,
#    'end': 256.12,
#    'text': ' 가.',
#    'tokens': [51364, 4147, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 74,
#    'seek': 23512,
#    'start': 256.12,
#    'end': 258.12,
#    'text': ' 어.',
#    'tokens': [51414, 9076, 13, 51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 75,
#    'seek': 23512,
#    'start': 258.12,
#    'end': 259.12,
#    'text': ' 그래.',
#    'tokens': [51514, 7080, 13, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 76,
#    'seek': 23512,
#    'start': 259.12,
#    'end': 260.12,
#    'text': ' 가.',
#    'tokens': [51564, 4147, 13, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 77,
#    'seek': 23512,
#    'start': 260.12,
#    'end': 262.12,
#    'text': ' 만한 사람은.',
#    'tokens': [51614, 14671, 3049, 12211, 2124, 13, 51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.34501351250542533,
#    'compression_ratio': 1.390557939914163,
#    'no_speech_prob': 0.0005413680337369442},
#   {'id': 78,
#    'seek': 26212,
#    'start': 262.12,
#    'end': 264.12,
#    'text': ' 만한 사람은.',
#    'tokens': [50364, 14671, 3049, 12211, 2124, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 79,
#    'seek': 26212,
#    'start': 264.12,
#    'end': 266.12,
#    'text': ' 상스러운 모습이 반가워요.',
#    'tokens': [50464,
#     8563,
#     12969,
#     40537,
#     27780,
#     1129,
#     16396,
#     1453,
#     35837,
#     13,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 80,
#    'seek': 26212,
#    'start': 266.12,
#    'end': 267.12,
#    'text': ' 뭐지?',
#    'tokens': [50564, 7034, 1831, 30, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 81,
#    'seek': 26212,
#    'start': 267.12,
#    'end': 272.12,
#    'text': ' 출시생의 비밀에 급방 삼촌도 한팬가?',
#    'tokens': [50614,
#     25420,
#     3833,
#     10175,
#     2785,
#     24241,
#     108,
#     222,
#     1517,
#     44728,
#     27630,
#     32391,
#     15241,
#     234,
#     3744,
#     4815,
#     7827,
#     105,
#     1453,
#     30,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 82,
#    'seek': 26212,
#    'start': 272.12,
#    'end': 277.12,
#    'text': ' 방금 이 팀에서 뭔 소리 안 났어요?',
#    'tokens': [50864,
#     10006,
#     4781,
#     2620,
#     31448,
#     4885,
#     43972,
#     21652,
#     4811,
#     2079,
#     105,
#     4213,
#     30,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 83,
#    'seek': 26212,
#    'start': 277.12,
#    'end': 278.12,
#    'text': ' 안 났는데.',
#    'tokens': [51114, 4811, 2079, 105, 4189, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 84,
#    'seek': 26212,
#    'start': 278.12,
#    'end': 279.12,
#    'text': ' 나는데?',
#    'tokens': [51164, 3948, 4189, 30, 51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 85,
#    'seek': 26212,
#    'start': 279.12,
#    'end': 280.12,
#    'text': ' 나 쏘요 나 쏘.',
#    'tokens': [51214, 3948, 40304, 246, 1495, 3948, 40304, 246, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 86,
#    'seek': 26212,
#    'start': 280.12,
#    'end': 282.12,
#    'text': ' 안 났어 덕호야.',
#    'tokens': [51264, 4811, 2079, 105, 3103, 5596, 243, 14705, 4248, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 87,
#    'seek': 26212,
#    'start': 288.12,
#    'end': 290.12,
#    'text': ' 나 5초로만 동갑게.',
#    'tokens': [51664,
#     3948,
#     1025,
#     15241,
#     2196,
#     1955,
#     5978,
#     11685,
#     27358,
#     1810,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.3457523492666391,
#    'compression_ratio': 1.3025641025641026,
#    'no_speech_prob': 0.00036937333061359823},
#   {'id': 88,
#    'seek': 29212,
#    'start': 292.12,
#    'end': 293.12,
#    'text': ' 아.',
#    'tokens': [50364, 2216, 13, 50414],
#    'temperature': 0.0,
#    'avg_logprob': -0.8677963629001524,
#    'compression_ratio': 0.9166666666666666,
#    'no_speech_prob': 7.59511676733382e-05},
#   {'id': 89,
#    'seek': 29212,
#    'start': 302.12,
#    'end': 304.12,
#    'text': ' 문 닦고 가.',
#    'tokens': [50864, 13086, 2515, 99, 1313, 4147, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.8677963629001524,
#    'compression_ratio': 0.9166666666666666,
#    'no_speech_prob': 7.59511676733382e-05},
#   {'id': 90,
#    'seek': 29212,
#    'start': 304.12,
#    'end': 305.12,
#    'text': ' 이걸 왜 이렇게.',
#    'tokens': [50964, 27107, 9883, 5483, 13, 51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.8677963629001524,
#    'compression_ratio': 0.9166666666666666,
#    'no_speech_prob': 7.59511676733382e-05},
#   {'id': 91,
#    'seek': 29212,
#    'start': 305.12,
#    'end': 306.12,
#    'text': ' 퇴퇴.',
#    'tokens': [51014, 1175, 229, 112, 169, 229, 112, 13, 51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.8677963629001524,
#    'compression_ratio': 0.9166666666666666,
#    'no_speech_prob': 7.59511676733382e-05},
#   {'id': 92,
#    'seek': 29212,
#    'start': 310.12,
#    'end': 312.12,
#    'text': ' 나 말 한만.',
#    'tokens': [51264, 3948, 7058, 10737, 6478, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.8677963629001524,
#    'compression_ratio': 0.9166666666666666,
#    'no_speech_prob': 7.59511676733382e-05},
#   {'id': 93,
#    'seek': 29212,
#    'start': 312.12,
#    'end': 313.12,
#    'text': ' 책상해.',
#    'tokens': [51364, 33623, 5979, 5302, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.8677963629001524,
#    'compression_ratio': 0.9166666666666666,
#    'no_speech_prob': 7.59511676733382e-05},
#   {'id': 94,
#    'seek': 32212,
#    'start': 323.12,
#    'end': 326.12,
#    'text': ' 아니 왜 이 했을든지 언제인데 웃이라노.',
#    'tokens': [50414,
#     5651,
#     9883,
#     2620,
#     8154,
#     1638,
#     167,
#     6646,
#     1831,
#     43790,
#     13481,
#     25014,
#     4250,
#     9316,
#     37524,
#     13,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 95,
#    'seek': 32212,
#    'start': 328.12,
#    'end': 329.12,
#    'text': ' 나 10만 한 말.',
#    'tokens': [50664, 3948, 1266, 5978, 4815, 7058, 13, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 96,
#    'seek': 32212,
#    'start': 329.12,
#    'end': 330.12,
#    'text': ' 고기 사기.',
#    'tokens': [50714, 9161, 2401, 4744, 2401, 13, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 97,
#    'seek': 32212,
#    'start': 332.12,
#    'end': 333.12,
#    'text': ' 뭐요?',
#    'tokens': [50864, 7034, 1495, 30, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 98,
#    'seek': 32212,
#    'start': 333.12,
#    'end': 337.12,
#    'text': ' 널 내 기억에 그대로 둔 신혜 뜻이 있겠지.',
#    'tokens': [50914,
#     3214,
#     238,
#     6918,
#     30935,
#     1517,
#     41711,
#     8108,
#     242,
#     13042,
#     5262,
#     250,
#     44774,
#     1129,
#     2297,
#     5137,
#     1831,
#     13,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 99,
#    'seek': 32212,
#    'start': 338.12,
#    'end': 340.12,
#    'text': ' 그렇게까지 얘기하지 못해서 골라라고.',
#    'tokens': [51164,
#     16104,
#     8786,
#     19641,
#     16175,
#     10239,
#     8275,
#     42142,
#     9316,
#     6954,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 100,
#    'seek': 32212,
#    'start': 340.12,
#    'end': 342.12,
#    'text': ' 마지막 방 볼 수는 수밖에.',
#    'tokens': [51264, 22722, 10006, 18001, 4446, 1098, 22297, 46902, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 101,
#    'seek': 32212,
#    'start': 342.12,
#    'end': 346.12,
#    'text': ' 옛날 생각해서 금너 하러 뚝딱 안 된다.',
#    'tokens': [51364,
#     48646,
#     8594,
#     8275,
#     4291,
#     2196,
#     23318,
#     5832,
#     6235,
#     39181,
#     251,
#     39147,
#     109,
#     4811,
#     16975,
#     1235,
#     13,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 102,
#    'seek': 32212,
#    'start': 346.12,
#    'end': 349.12,
#    'text': ' 고유 번호 있어서 내가 팔지도 못한다고.',
#    'tokens': [51564,
#     9161,
#     19062,
#     10212,
#     14705,
#     27937,
#     10474,
#     37110,
#     39871,
#     10239,
#     3049,
#     7726,
#     13,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.5044942583356585,
#    'compression_ratio': 1.3618677042801557,
#    'no_speech_prob': 0.001318581635132432},
#   {'id': 103,
#    'seek': 34912,
#    'start': 350.12,
#    'end': 352.12,
#    'text': ' 골라 저럴거야.',
#    'tokens': [50414, 42142, 2742, 13163, 253, 112, 33328, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 104,
#    'seek': 34912,
#    'start': 354.12,
#    'end': 356.12,
#    'text': ' 소개팅하기만 해 아주.',
#    'tokens': [50614, 42784, 27086, 2240, 7091, 6478, 11683, 22360, 13, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 105,
#    'seek': 34912,
#    'start': 356.12,
#    'end': 359.12,
#    'text': ' 고유 유분이 한 대 무슨.',
#    'tokens': [50714,
#     9161,
#     19062,
#     22262,
#     6072,
#     1129,
#     4815,
#     5971,
#     22712,
#     13,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 106,
#    'seek': 34912,
#    'start': 361.12,
#    'end': 363.12,
#    'text': ' 유분이요.',
#    'tokens': [50964, 22262, 6072, 3946, 1206, 13, 51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 107,
#    'seek': 34912,
#    'start': 363.12,
#    'end': 365.12,
#    'text': ' 라고 했다.',
#    'tokens': [51064, 43281, 8154, 1235, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 108,
#    'seek': 34912,
#    'start': 365.12,
#    'end': 366.12,
#    'text': ' 어디 사나요?',
#    'tokens': [51164, 20879, 6606, 26057, 30, 51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 109,
#    'seek': 34912,
#    'start': 368.12,
#    'end': 369.12,
#    'text': ' 저 스타일 아니시라니까.',
#    'tokens': [51314, 4841, 45881, 5651, 10426, 2742, 5690, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 110,
#    'seek': 34912,
#    'start': 369.12,
#    'end': 372.12,
#    'text': ' 이 팀이 적상해 좀 맞아요?',
#    'tokens': [51364,
#     2620,
#     31448,
#     1129,
#     14370,
#     5979,
#     5302,
#     6796,
#     35273,
#     30,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 111,
#    'seek': 34912,
#    'start': 372.12,
#    'end': 374.12,
#    'text': ' 어떻게 내 동의도 없어요?',
#    'tokens': [51514, 12952, 6918, 11685, 673, 8226, 31162, 30, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 112,
#    'seek': 34912,
#    'start': 374.12,
#    'end': 376.12,
#    'text': ' 어떻게 여기저기 딱 다 커밍이 나왔을래요?',
#    'tokens': [51614,
#     12952,
#     7543,
#     11738,
#     2401,
#     16681,
#     4279,
#     39573,
#     108,
#     235,
#     1129,
#     26374,
#     1638,
#     167,
#     4241,
#     1495,
#     30,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 113,
#    'seek': 34912,
#    'start': 376.12,
#    'end': 378.12,
#    'text': ' 아 아패다 아패가 왼쪽으로 지켜라.',
#    'tokens': [51714,
#     2216,
#     2216,
#     7827,
#     101,
#     1235,
#     2216,
#     7827,
#     101,
#     1453,
#     4186,
#     120,
#     16094,
#     4130,
#     4704,
#     12397,
#     2163,
#     2742,
#     13,
#     51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.5261912223620292,
#    'compression_ratio': 1.4074074074074074,
#    'no_speech_prob': 0.00041989635792560875},
#   {'id': 114,
#    'seek': 37912,
#    'start': 380.12,
#    'end': 381.12,
#    'text': ' 왜 줄 아네요?',
#    'tokens': [50414, 9883, 15320, 9200, 12974, 30, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 115,
#    'seek': 37912,
#    'start': 381.12,
#    'end': 385.12,
#    'text': ' 아니 너 운전하는 거 보니까 진짜 어른된 것 같아.',
#    'tokens': [50464,
#     5651,
#     12963,
#     4709,
#     47595,
#     7116,
#     3675,
#     25612,
#     7106,
#     4863,
#     98,
#     1397,
#     14987,
#     4431,
#     23396,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 116,
#    'seek': 37912,
#    'start': 385.12,
#    'end': 386.12,
#    'text': ' 차선 차선.',
#    'tokens': [50664, 15391, 12421, 15391, 12421, 13, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 117,
#    'seek': 37912,
#    'start': 386.12,
#    'end': 387.12,
#    'text': ' 핸들 꽉 꽉 줘.',
#    'tokens': [50714,
#     1362,
#     1397,
#     2403,
#     24378,
#     231,
#     24378,
#     231,
#     41926,
#     13,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 118,
#    'seek': 37912,
#    'start': 387.12,
#    'end': 388.12,
#    'text': ' 아 다 보고 있어.',
#    'tokens': [50764, 2216, 4279, 18942, 17300, 13, 50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 119,
#    'seek': 37912,
#    'start': 388.12,
#    'end': 389.12,
#    'text': ' 아니지 알지.',
#    'tokens': [50814, 5651, 1831, 9457, 1831, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 120,
#    'seek': 37912,
#    'start': 389.12,
#    'end': 391.12,
#    'text': ' 다 알지 내가 신계속을 해.',
#    'tokens': [50864,
#     4279,
#     9457,
#     1831,
#     10474,
#     13042,
#     14597,
#     11194,
#     1638,
#     11683,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 121,
#    'seek': 37912,
#    'start': 391.12,
#    'end': 393.12,
#    'text': ' 정석이 처음 타봐서.',
#    'tokens': [50964,
#     4980,
#     17075,
#     1129,
#     18736,
#     8675,
#     2366,
#     16808,
#     2393,
#     13,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 122,
#    'seek': 37912,
#    'start': 394.12,
#    'end': 396.12,
#    'text': ' 좀 좋아해 줘.',
#    'tokens': [51114, 6796, 10805, 5302, 41926, 13, 51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 123,
#    'seek': 37912,
#    'start': 396.12,
#    'end': 397.12,
#    'text': ' 좋아해 줘.',
#    'tokens': [51214, 10805, 5302, 41926, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 124,
#    'seek': 37912,
#    'start': 397.12,
#    'end': 398.12,
#    'text': ' 좋아해 줘.',
#    'tokens': [51264, 10805, 5302, 41926, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 125,
#    'seek': 37912,
#    'start': 398.12,
#    'end': 399.12,
#    'text': ' 왼쪽 왼쪽.',
#    'tokens': [51314, 4186, 120, 16094, 4186, 120, 16094, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 126,
#    'seek': 37912,
#    'start': 400.12,
#    'end': 403.12,
#    'text': ' 아 진짜 어디 가는데요?',
#    'tokens': [51414, 2216, 7106, 20879, 4147, 14586, 30, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 127,
#    'seek': 37912,
#    'start': 404.12,
#    'end': 407.12,
#    'text': ' 그 좌회전한테 깜빡이 키라고 깜빡이 항상.',
#    'tokens': [51614,
#     4296,
#     3340,
#     234,
#     15048,
#     8210,
#     15863,
#     8394,
#     2163,
#     117,
#     94,
#     1129,
#     21959,
#     2990,
#     6954,
#     8394,
#     2163,
#     117,
#     94,
#     1129,
#     30747,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.3901131170259105,
#    'compression_ratio': 1.546938775510204,
#    'no_speech_prob': 0.0005511938943527639},
#   {'id': 128,
#    'seek': 40912,
#    'start': 410.12,
#    'end': 411.12,
#    'text': ' 아...',
#    'tokens': [50414, 2216, 485, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.5813650455114976,
#    'compression_ratio': 1.1151079136690647,
#    'no_speech_prob': 0.0001203717474709265},
#   {'id': 129,
#    'seek': 40912,
#    'start': 412.12,
#    'end': 415.12,
#    'text': ' 산패인에 7도에서 구도사이가 딱이지.',
#    'tokens': [50514,
#     29589,
#     7827,
#     101,
#     4215,
#     1517,
#     1614,
#     3744,
#     4885,
#     17386,
#     1838,
#     5727,
#     19556,
#     16681,
#     25721,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5813650455114976,
#    'compression_ratio': 1.1151079136690647,
#    'no_speech_prob': 0.0001203717474709265},
#   {'id': 130,
#    'seek': 40912,
#    'start': 419.12,
#    'end': 420.12,
#    'text': ' 그 바깥쪽.',
#    'tokens': [50864, 4296, 12704, 2900, 98, 16094, 13, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.5813650455114976,
#    'compression_ratio': 1.1151079136690647,
#    'no_speech_prob': 0.0001203717474709265},
#   {'id': 131,
#    'seek': 40912,
#    'start': 424.12,
#    'end': 426.12,
#    'text': ' 아 왜 안 마셔도 치하는 거 같네 나는.',
#    'tokens': [51114,
#     2216,
#     9883,
#     4811,
#     6437,
#     6961,
#     40720,
#     18447,
#     7116,
#     3675,
#     4385,
#     17507,
#     17955,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.5813650455114976,
#    'compression_ratio': 1.1151079136690647,
#    'no_speech_prob': 0.0001203717474709265},
#   {'id': 132,
#    'seek': 40912,
#    'start': 426.12,
#    'end': 428.12,
#    'text': ' 벌써 치하면 어떻게 해.',
#    'tokens': [51214, 49175, 18447, 16283, 12952, 11683, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.5813650455114976,
#    'compression_ratio': 1.1151079136690647,
#    'no_speech_prob': 0.0001203717474709265},
#   {'id': 133,
#    'seek': 43912,
#    'start': 440.12,
#    'end': 441.12,
#    'text': ' 어이씨.',
#    'tokens': [50414, 9076, 3946, 242, 101, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 134,
#    'seek': 43912,
#    'start': 441.12,
#    'end': 442.12,
#    'text': ' 어이씨.',
#    'tokens': [50464, 9076, 3946, 242, 101, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 135,
#    'seek': 43912,
#    'start': 442.12,
#    'end': 443.12,
#    'text': ' 산쪽까지 왜 이래.',
#    'tokens': [50514, 29589, 16094, 8786, 9883, 2892, 4241, 13, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 136,
#    'seek': 43912,
#    'start': 446.12,
#    'end': 447.12,
#    'text': ' 괜찮으세요?',
#    'tokens': [50714, 18286, 10307, 7046, 30, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 137,
#    'seek': 43912,
#    'start': 448.12,
#    'end': 449.12,
#    'text': ' 안색이 안 좋으세요.',
#    'tokens': [50814, 4811, 15554, 1129, 4811, 5008, 10307, 7046, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 138,
#    'seek': 43912,
#    'start': 449.12,
#    'end': 450.12,
#    'text': ' 아 괜찮죠?',
#    'tokens': [50864, 2216, 18286, 5837, 30, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 139,
#    'seek': 43912,
#    'start': 450.12,
#    'end': 451.12,
#    'text': ' 오케이.',
#    'tokens': [50914, 30567, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 140,
#    'seek': 43912,
#    'start': 452.12,
#    'end': 453.12,
#    'text': ' 집 또 얼마 추웠어.',
#    'tokens': [51014, 12111, 7992, 44859, 17435, 36450, 3103, 13, 51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 141,
#    'seek': 43912,
#    'start': 454.12,
#    'end': 455.12,
#    'text': ' 한잔 하시겠어요?',
#    'tokens': [51114, 4815, 48267, 3369, 3833, 30826, 30, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 142,
#    'seek': 43912,
#    'start': 456.12,
#    'end': 457.12,
#    'text': ' 네.',
#    'tokens': [51214, 8808, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 143,
#    'seek': 43912,
#    'start': 457.12,
#    'end': 458.12,
#    'text': ' 저 집을 맞습니다.',
#    'tokens': [51264, 4841, 12111, 1638, 9172, 3115, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 144,
#    'seek': 43912,
#    'start': 460.12,
#    'end': 461.12,
#    'text': ' 김대표님.',
#    'tokens': [51414, 43629, 3638, 18923, 9466, 13, 51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 145,
#    'seek': 43912,
#    'start': 461.12,
#    'end': 462.12,
#    'text': ' 김대표님.',
#    'tokens': [51464, 43629, 3638, 18923, 9466, 13, 51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 146,
#    'seek': 43912,
#    'start': 462.12,
#    'end': 464.12,
#    'text': ' 아 진짜 정신들 좀 하자.',
#    'tokens': [51514,
#     2216,
#     7106,
#     4980,
#     1995,
#     4673,
#     2403,
#     6796,
#     3369,
#     4264,
#     13,
#     51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 147,
#    'seek': 43912,
#    'start': 464.12,
#    'end': 467.12,
#    'text': ' 삼촌들 너무 굳이해하고 천진 난만 해.',
#    'tokens': [51614,
#     32391,
#     15241,
#     2457,
#     2403,
#     6924,
#     4946,
#     111,
#     1129,
#     5302,
#     7040,
#     31076,
#     8097,
#     2079,
#     2163,
#     6478,
#     11683,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.40944164030013547,
#    'compression_ratio': 1.4220183486238531,
#    'no_speech_prob': 0.0003641093207988888},
#   {'id': 148,
#    'seek': 46912,
#    'start': 470.12,
#    'end': 471.12,
#    'text': ' 뭐지?',
#    'tokens': [50414, 7034, 1831, 30, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 149,
#    'seek': 46912,
#    'start': 471.12,
#    'end': 473.12,
#    'text': ' 왜 이머리 입에 짝 붙지?',
#    'tokens': [50464,
#     9883,
#     2892,
#     101,
#     14981,
#     10051,
#     1517,
#     2334,
#     251,
#     24618,
#     1831,
#     30,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 150,
#    'seek': 46912,
#    'start': 474.12,
#    'end': 475.12,
#    'text': ' 너.',
#    'tokens': [50614, 12963, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 151,
#    'seek': 46912,
#    'start': 476.12,
#    'end': 477.12,
#    'text': ' 너.',
#    'tokens': [50714, 12963, 13, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 152,
#    'seek': 46912,
#    'start': 481.12,
#    'end': 482.12,
#    'text': ' 아휴.',
#    'tokens': [50964, 2216, 38909, 112, 13, 51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 153,
#    'seek': 46912,
#    'start': 482.12,
#    'end': 483.12,
#    'text': ' 아휴.',
#    'tokens': [51014, 2216, 38909, 112, 13, 51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 154,
#    'seek': 46912,
#    'start': 483.12,
#    'end': 484.12,
#    'text': ' 아휴.',
#    'tokens': [51064, 2216, 38909, 112, 13, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 155,
#    'seek': 46912,
#    'start': 484.12,
#    'end': 485.12,
#    'text': ' 무슨 노래.',
#    'tokens': [51114, 22712, 24678, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 156,
#    'seek': 46912,
#    'start': 485.12,
#    'end': 486.12,
#    'text': ' 이 놈 수 못해요.',
#    'tokens': [51164, 2620, 10091, 230, 4446, 10239, 15788, 13, 51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 157,
#    'seek': 46912,
#    'start': 486.12,
#    'end': 487.12,
#    'text': ' 이렇게 많은.',
#    'tokens': [51214, 5483, 18494, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 158,
#    'seek': 46912,
#    'start': 488.12,
#    'end': 490.12,
#    'text': ' 사람들 가운데.',
#    'tokens': [51314, 39570, 44627, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 159,
#    'seek': 46912,
#    'start': 491.12,
#    'end': 493.12,
#    'text': ' 너를 만난 건',
#    'tokens': [51464, 3214, 31567, 8165, 16662, 13507, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 160,
#    'seek': 46912,
#    'start': 494.12,
#    'end': 496.12,
#    'text': ' 정말의 운이야.',
#    'tokens': [51614, 12793, 2785, 4709, 112, 15374, 13, 51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.46319502875918434,
#    'compression_ratio': 1.2582781456953642,
#    'no_speech_prob': 0.0025407865177839994},
#   {'id': 161,
#    'seek': 49912,
#    'start': 499.12,
#    'end': 501.12,
#    'text': ' 이렇게 넓은',
#    'tokens': [50364, 5483, 3214, 241, 2124, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686},
#   {'id': 162,
#    'seek': 49912,
#    'start': 502.12,
#    'end': 504.12,
#    'text': ' 세상 한 건데',
#    'tokens': [50514, 37990, 4815, 29201, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686},
#   {'id': 163,
#    'seek': 49912,
#    'start': 504.12,
#    'end': 505.12,
#    'text': ' 다같이.',
#    'tokens': [50614, 4279, 22226, 1129, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686},
#   {'id': 164,
#    'seek': 49912,
#    'start': 506.12,
#    'end': 508.12,
#    'text': ' 그들 만난 건',
#    'tokens': [50714, 2003, 2403, 8165, 16662, 13507, 50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686},
#   {'id': 165,
#    'seek': 49912,
#    'start': 508.12,
#    'end': 511.12,
#    'text': ' 나 역시 기쁨이야.',
#    'tokens': [50814, 3948, 34522, 7047, 15404, 101, 15374, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686},
#   {'id': 166,
#    'seek': 49912,
#    'start': 512.12,
#    'end': 514.12,
#    'text': ' 이렇게 많은',
#    'tokens': [51014, 5483, 18494, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686},
#   {'id': 167,
#    'seek': 49912,
#    'start': 514.12,
#    'end': 518.12,
#    'text': ' 사람들 가운데.',
#    'tokens': [51114, 39570, 44627, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.3582077469936637,
#    'compression_ratio': 1.0769230769230769,
#    'no_speech_prob': 0.010490148328244686}],
#  'language': 'ko'}

# %%
transcript = result['text']
transcript
# Out:
# ' 300살이면 한창 아프고 그럴 때지. 괜찮아. 왜? 다시 사실 하나. 답을 어떻게 위해선 답과 가까운 자에게 다가가야 한다. 뭔 소리야? 야 무슨 짓이야 이게 너 하나야. 역시 너에게 나무것도 보이지 않는군. 그저 따뜻할 때. 아 깜짝짝 아파 아파. 야 대소 어떻게 할 거야? 너 꼭 잘 먹었어. 대소. 이소 어떻게 할 거야? 이소. 아 더워. 더워 더워. 잘라버려야 돼. 소독. 이런면 됐죠? 됐네. 다 됐네 소독이. 이제 괜찮아. 걱정 마. 왜 여기로 와 슈퍼 가주면서. 아 궁금하잖아. 내가 진짜 궁금하잖아 처음 먹어봐. 진짜 진짜 처음이야. 궁금하를 처음 먹는 게 아니라 궁금한 처음 먹는 길을 처음 한 것 같은데. 세상에 역시 일을 생활권 지구천 한부 당시 내. 어떻게 이런 우연이 있을 수 있죠? 뭐해 이런 우연 앞에서. 두 분 인사 안 하세요? 우연이 마주쳐도 인사 안 하기로 해서. 인사 안 하기로 했어? 하하. 두 사람 오늘 전체적으로 노른자와 흰자가 안 내 계란으로 해. – icy 홈‑ licence 당림owned? 콩나물이네죽이pa Class finely. 우리 학교 되게 좋죠? 좋네. 되게 싫은 것들 몇 가지 있었는데요? 저에게 좋은 것도 있었어요. 좋은 건 원래 늦게 찾아오나봐요. 아저씨처럼. 일찍 왔는데 몇 반인지 몰랐어. 말고요. 덕박 덕박 덕박 덕박 덕박. 잠시만, 걱정해요. 금방 삼촌. 어 왔어, 무슨 일이야? 회사에서 이상한 사람 만나가지고 마음이 다 정승하고 해서. 끝방 삼촌 잘 계시나 해서 한번 와 봤죠. 근데 끝방 삼촌. 어? 삼촌이면 삼촌이지. 삼촌은 왜 끝방 삼촌이에요? 그러고 보니 끝방 삼촌 언제부터 우리 집에 살았죠? 부동산 계약서 보면 알잖아. 아. 근데 왜 술 병원 두 병인가요? 누구 왔어요? 내가 양손에 한 벽씩 주고 맛있는 걸 선호해서. 그럼 소파 뒤에 있는 저 발 뒤꿈치는 뭐예요? 야 이게 소파가 참 예쁘다. 그럼 주인이 안보기 높아. 마무리가 좋아가지고. 어? 아까 그 이상한 그 시안한. 머리 하셨네요? 머리가 잘 됐다구나. 나는 저자의 친구 이 집에 놀러. 갈 거야. 갈려던 참이었어. 즐거웠어. 가. 어. 그래. 가. 만한사 방금 왔네. 상스러운 옷을 입었군. 뭐지? 출시생의 비밀에 끝방 삼촌도 한 벩가? 방금 이 팀에서 뭔 소리 안 났어요? 안 났는데. 나는데? 낯수예요? 낯수. 덕후야. 나 5초론만 동갑게. 문 닭구간! 투명붙여. 나 말 한만. 색사기. 아니 왜 이 애쓰는 그런지가 언제인데 웃이라노. 나 10만 한만. 고기사기. 야. 널 내 기억에 그대로 둔 신혜 뜻이 있겠지. 그렇게까지 얘기하지 못해서 골라놔고. 마지막 방금 벌써는 수박해. 옛날 생각해서 금방 알아 뚝딱 안 된다. 고유 번호 있어서 내가 나 팔지도 못한다고. 골라 저럭군. 소개팅하기만 해 아주. 거의 6분이 한 대 무슨. 6분이 오라고 했다. 어디 사나요? 저 스타일 아니시라니까. 인튀고 적상해준 맛재료? 어떻게 내 동의도 없어요? 어떻게 여기저기다 다 커밍이 나왔을래요? 앞에 봐. 왼쪽으로 다시 찾아. 왜 불하네요? 아니 너 운전하는 거 보니까 진짜 어른된 것 같아. 차선 차선. 핸들 꽉 쫑. 아 나 보고 있어. 아니지. 다 알지. 내가 신기했어. 그래. 좋습니다. 처음 타봐서. 좀 좋아해 줘. 저의 전 왼쪽 왼쪽. 아 진짜. 어디 가는데요? 그 좌회전인데 깜빡이 키라고 깜빡이 항상. 산패연에 7도에서 구도사회가 딱이지. 그 빨갛자. 아 왜 안 마셔도 치하는 거 같네 나는. 벌써 치하면 어떻게 해. 어이씨. 3쪽까지 왜 이래. 괜찮으세요? 안 색이 안 좋으세요. 괜찮으세요? 안 색이 안 좋으세요. 괜찮지? 오케이. 집도 얼마 추웠어. 한잔 하시겠어요? 네. 저 지금 뭐. 김대표님. 김대표님. 아 진짜 저심들 좀 하자. 3손 들 너무 굳이해하고 천진 난만 해. 뭐지? 왜 이머리 입에 짝 붙지? 너. 아 왜 안 해요 무슨 노래. 왜 이렇게 많은 사람들 가운데 너를 만난 건 정말의 운이야. 이렇게 넓은 새 사랑 가운데. 다같이. 그들 만난 건 나 역시 기쁨이야. 이렇게 많은 사람들 가운데.'

# %%
matches = search_text(transcript, target_text)
matches
# Out:
# extract_audio processing...
# [(11, 20)]

# %%
start_time, end_time, query = search_text(result, target_text)
# Out:
# search_text processing...
# (0.0, 3.18, '아프고 그럴 때지')

# %%
time_matches = map_time(result, matches)
time_matches
# Out:
# mapping time processing...
# [(10.06, 20.98)]

# %%
print_results(time_matches)
# Out:
# 대사 발견: 10.06초 - 20.98초

# %%
from IPython.display import Video, HTML
import base64
from pathlib import Path

def play_video_basic(video_path):
    """기본 비디오 플레이어"""
    return Video(video_path)

def play_video_with_controls(video_path, width=640):
    """HTML5 비디오 플레이어 (컨트롤 포함)"""
    video_path = Path(video_path)
    video_type = f'video/{video_path.suffix[1:]}'  # .mp4 -> video/mp4
    
    html = f'''
    <video width="{width}" controls>
        <source src="{video_path}" type="{video_type}">
        Your browser does not support the video tag.
    </video>
    '''
    return HTML(html)

def play_video_segment(video_path, start_time=0, end_time=None, width=640):
    """특정 구간 재생"""
    video_path = Path(video_path)
    video_type = f'video/{video_path.suffix[1:]}'
    
    # t=시작시간#t=끝시간 형식으로 구간 지정
    time_params = f"#t={start_time}"
    if end_time:
        time_params += f",{end_time}"
    
    html = f'''
    <video width="{width}" controls>
        <source src="{video_path}{time_params}" type="{video_type}">
        Your browser does not support the video tag.
    </video>
    '''
    return HTML(html)

# 사용 예시:
video_path = "./assets/Goblin_test.mp4"

# 1. 기본 재생
basic_player = play_video_basic(video_path)
#display(basic_player)

# 2. 컨트롤러가 있는 플레이어
controller_player = play_video_with_controls(video_path, width=800)
#display(controller_player)

# 3. 특정 구간 재생 (예: 10초부터 20초까지)
segment_player = play_video_segment(video_path, start_time=10, end_time=20, width=800)
display(segment_player)
# Out:
#     <video width="800" controls>
#         <source src="assets/Goblin_test.mp4#t=10,20" type="video/mp4">
#         Your browser does not support the video tag.
#     </video>

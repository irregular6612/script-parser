# %%
from moviepy.editor import VideoFileClip

def extract_audio(video_path, audio_path):
    print("extract_audio processing...")
    video = VideoFileClip(video_path)
    audio = video.audio
    audio.write_audiofile(audio_path)

# %%
import whisper

def transcribe_audio(audio_path):
    print("transcribe_audio processing...")
    model = whisper.load_model("base")
    result = model.transcribe(audio_path)
    return result

# %%
import re

def search_text(transcript, query):
    print("extract_audio processing...")
    matches = re.finditer(query, transcript, re.IGNORECASE)
    return [match.span() for match in matches]

# %%
def map_time(result, matches):
    print("mapping time processing...")
    segments = result["segments"]
    time_matches = []
    for match in matches:
        start_time = next(seg["start"] for seg in segments if seg["start"] <= match[0] < seg["end"])
        end_time = next(seg["end"] for seg in reversed(segments) if seg["start"] < match[1] <= seg["end"])
        time_matches.append((start_time, end_time))
    return time_matches

# %%
def print_results(time_matches):
    for start, end in time_matches:
        print(f"대사 발견: {start:.2f}초 - {end:.2f}초")

# %%
video_path = "./assets/Goblin_test.mp4"
audio_path = "./assets/Goblin_test.wav"

target_text = "아프고 그럴 때지"

extract_audio(video_path, audio_path)
# Out:
# extract_audio processing...
# MoviePy - Writing audio in ./assets/Goblin_test.wav
# MoviePy - Done.

# %%
result = transcribe_audio(audio_path)
result
# Out:
# transcribe_audio processing...
# {'text': ' 300살이면 한창 아프고 그럴 때지. 괜찮아. 왜? 다시 사실 하나. 답을 어떻게 위해선 답과 가까운 자에게 다가가야 한다. 뭔 소리야? 야 무슨 짓이야 이게 너 하나야. 역시 너에게 나무것도 보이지 않는군. 그저 따뜻할 때. 아 깜짝짝 아파 아파. 야 대소 어떻게 할 거야? 너 꼭 잘 먹었어. 대소. 이소 어떻게 할 거야? 이소. 아 더워. 더워 더워. 잘라버려야 돼. 소독. 이런면 됐죠? 됐네. 다 됐네 소독이. 이제 괜찮아. 걱정 마. 왜 여기로 와 슈퍼 가주면서. 아 궁금하잖아. 내가 진짜 궁금하잖아 처음 먹어봐. 진짜 진짜 처음이야. 궁금하를 처음 먹는 게 아니라 궁금한 처음 먹는 길을 처음 한 것 같은데. 세상에 역시 일을 생활권 지구천 한부 당시 내. 어떻게 이런 우연이 있을 수 있죠? 뭐해 이런 우연 앞에서. 두 분 인사 안 하세요? 우연이 마주쳐도 인사 안 하기로 해서. 인사 안 하기로 했어? 하하. 두 사람 오늘 전체적으로 노른자와 흰자가 안 내 계란으로 해. – icy 홈‑ licence 당림owned? 콩나물이네죽이pa Class finely. 우리 학교 되게 좋죠? 좋네. 되게 싫은 것들 몇 가지 있었는데요? 저에게 좋은 것도 있었어요. 좋은 건 원래 늦게 찾아오나봐요. 아저씨처럼. 일찍 왔는데 몇 반인지 몰랐어. 말고요. 덕박 덕박 덕박 덕박 덕박. 잠시만, 걱정해요. 금방 삼촌. 어 왔어, 무슨 일이야? 회사에서 이상한 사람 만나가지고 마음이 다 정승하고 해서. 끝방 삼촌 잘 계시나 해서 한번 와 봤죠. 근데 끝방 삼촌. 어? 삼촌이면 삼촌이지. 삼촌은 왜 끝방 삼촌이에요? 그러고 보니 끝방 삼촌 언제부터 우리 집에 살았죠? 부동산 계약서 보면 알잖아. 아. 근데 왜 술 병원 두 병인가요? 누구 왔어요? 내가 양손에 한 벽씩 주고 맛있는 걸 선호해서. 그럼 소파 뒤에 있는 저 발 뒤꿈치는 뭐예요? 야 이게 소파가 참 예쁘다. 그럼 주인이 안보기 높아. 마무리가 좋아가지고. 어? 아까 그 이상한 그 시안한. 머리 하셨네요? 머리가 잘 됐다구나. 나는 저자의 친구 이 집에 놀러. 갈 거야. 갈려던 참이었어. 즐거웠어. 가. 어. 그래. 가. 만한사 방금 왔네. 상스러운 옷을 입었군. 뭐지? 출시생의 비밀에 끝방 삼촌도 한 벩가? 방금 이 팀에서 뭔 소리 안 났어요? 안 났는데. 나는데? 낯수예요? 낯수. 덕후야. 나 5초론만 동갑게. 문 닭구간! 투명붙여. 나 말 한만. 색사기. 아니 왜 이 애쓰는 그런지가 언제인데 웃이라노. 나 10만 한만. 고기사기. 야. 널 내 기억에 그대로 둔 신혜 뜻이 있겠지. 그렇게까지 얘기하지 못해서 골라놔고. 마지막 방금 벌써는 수박해. 옛날 생각해서 금방 알아 뚝딱 안 된다. 고유 번호 있어서 내가 나 팔지도 못한다고. 골라 저럭군. 소개팅하기만 해 아주. 거의 6분이 한 대 무슨. 6분이 오라고 했다. 어디 사나요? 저 스타일 아니시라니까. 인튀고 적상해준 맛재료? 어떻게 내 동의도 없어요? 어떻게 여기저기다 다 커밍이 나왔을래요? 앞에 봐. 왼쪽으로 다시 찾아. 왜 불하네요? 아니 너 운전하는 거 보니까 진짜 어른된 것 같아. 차선 차선. 핸들 꽉 쫑. 아 나 보고 있어. 아니지. 다 알지. 내가 신기했어. 그래. 좋습니다. 처음 타봐서. 좀 좋아해 줘. 저의 전 왼쪽 왼쪽. 아 진짜. 어디 가는데요? 그 좌회전인데 깜빡이 키라고 깜빡이 항상. 산패연에 7도에서 구도사회가 딱이지. 그 빨갛자. 아 왜 안 마셔도 치하는 거 같네 나는. 벌써 치하면 어떻게 해. 어이씨. 3쪽까지 왜 이래. 괜찮으세요? 안 색이 안 좋으세요. 괜찮으세요? 안 색이 안 좋으세요. 괜찮지? 오케이. 집도 얼마 추웠어. 한잔 하시겠어요? 네. 저 지금 뭐. 김대표님. 김대표님. 아 진짜 저심들 좀 하자. 3손 들 너무 굳이해하고 천진 난만 해. 뭐지? 왜 이머리 입에 짝 붙지? 너. 아 왜 안 해요 무슨 노래. 왜 이렇게 많은 사람들 가운데 너를 만난 건 정말의 운이야. 이렇게 넓은 새 사랑 가운데. 다같이. 그들 만난 건 나 역시 기쁨이야. 이렇게 많은 사람들 가운데.',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 3.18,
#    'text': ' 300살이면 한창 아프고 그럴 때지.',
#    'tokens': [50364,
#     6641,
#     26082,
#     42935,
#     4815,
#     36935,
#     2216,
#     19514,
#     1313,
#     45372,
#     7765,
#     1831,
#     13,
#     50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 1,
#    'seek': 0,
#    'start': 3.98,
#    'end': 4.98,
#    'text': ' 괜찮아.',
#    'tokens': [50563, 45058, 13, 50613],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 2,
#    'seek': 0,
#    'start': 7.68,
#    'end': 10.06,
#    'text': ' 왜? 다시 사실 하나.',
#    'tokens': [50748, 9883, 30, 15463, 14504, 12261, 13, 50867],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 3,
#    'seek': 0,
#    'start': 10.06,
#    'end': 13.92,
#    'text': ' 답을 어떻게 위해선 답과 가까운 자에게 다가가야 한다.',
#    'tokens': [50867,
#     41918,
#     1638,
#     12952,
#     9491,
#     7002,
#     226,
#     254,
#     41918,
#     7097,
#     44913,
#     9996,
#     5650,
#     15989,
#     4279,
#     1453,
#     1453,
#     4248,
#     44005,
#     13,
#     51060],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 4,
#    'seek': 0,
#    'start': 13.92,
#    'end': 15.06,
#    'text': ' 뭔 소리야?',
#    'tokens': [51060, 43972, 21652, 4248, 30, 51117],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 5,
#    'seek': 0,
#    'start': 18.28,
#    'end': 20.98,
#    'text': ' 야 무슨 짓이야 이게 너 하나야.',
#    'tokens': [51278,
#     13450,
#     22712,
#     2334,
#     241,
#     15374,
#     10496,
#     12963,
#     12261,
#     4248,
#     13,
#     51413],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 6,
#    'seek': 0,
#    'start': 20.98,
#    'end': 24.12,
#    'text': ' 역시 너에게 나무것도 보이지 않는군.',
#    'tokens': [51413,
#     34522,
#     12963,
#     15989,
#     12623,
#     18129,
#     47450,
#     6330,
#     25721,
#     34790,
#     24707,
#     13,
#     51570],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 7,
#    'seek': 0,
#    'start': 24.12,
#    'end': 25.400000000000002,
#    'text': ' 그저 따뜻할 때.',
#    'tokens': [51570, 4296, 11738, 15933, 250, 119, 7999, 7765, 13, 51634],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 8,
#    'seek': 0,
#    'start': 25.400000000000002,
#    'end': 27.64,
#    'text': ' 아 깜짝짝 아파 아파.',
#    'tokens': [51634, 2216, 8394, 250, 28624, 28624, 46438, 46438, 13, 51746],
#    'temperature': 0.0,
#    'avg_logprob': -0.6270298767089844,
#    'compression_ratio': 1.3547008547008548,
#    'no_speech_prob': 0.00927018839865923},
#   {'id': 9,
#    'seek': 2764,
#    'start': 27.84,
#    'end': 29.740000000000002,
#    'text': ' 야 대소 어떻게 할 거야?',
#    'tokens': [50374, 13450, 5971, 12012, 12952, 8981, 15928, 30, 50469],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 10,
#    'seek': 2764,
#    'start': 29.740000000000002,
#    'end': 30.82,
#    'text': ' 너 꼭 잘 먹었어.',
#    'tokens': [50469, 12963, 25881, 6644, 6554, 30562, 13, 50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 11,
#    'seek': 2764,
#    'start': 30.82,
#    'end': 31.62,
#    'text': ' 대소.',
#    'tokens': [50523, 5971, 12012, 13, 50563],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 12,
#    'seek': 2764,
#    'start': 31.62,
#    'end': 32.980000000000004,
#    'text': ' 이소 어떻게 할 거야?',
#    'tokens': [50563, 4329, 228, 234, 12952, 8981, 15928, 30, 50631],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 13,
#    'seek': 2764,
#    'start': 32.980000000000004,
#    'end': 33.9,
#    'text': ' 이소.',
#    'tokens': [50631, 4329, 228, 234, 13, 50677],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 14,
#    'seek': 2764,
#    'start': 33.9,
#    'end': 34.980000000000004,
#    'text': ' 아 더워.',
#    'tokens': [50677, 2216, 6990, 10086, 13, 50731],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 15,
#    'seek': 2764,
#    'start': 34.980000000000004,
#    'end': 35.96,
#    'text': ' 더워 더워.',
#    'tokens': [50731, 6990, 10086, 6990, 10086, 13, 50780],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 16,
#    'seek': 2764,
#    'start': 35.96,
#    'end': 36.980000000000004,
#    'text': ' 잘라버려야 돼.',
#    'tokens': [50780, 24041, 9316, 24410, 5743, 4248, 11080, 13, 50831],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 17,
#    'seek': 2764,
#    'start': 41.120000000000005,
#    'end': 42.120000000000005,
#    'text': ' 소독.',
#    'tokens': [51038, 13062, 19079, 13, 51088],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 18,
#    'seek': 2764,
#    'start': 42.88,
#    'end': 44.120000000000005,
#    'text': ' 이런면 됐죠?',
#    'tokens': [51126, 2892, 253, 2004, 2708, 16718, 5837, 30, 51188],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 19,
#    'seek': 2764,
#    'start': 48.400000000000006,
#    'end': 50.1,
#    'text': ' 됐네.',
#    'tokens': [51402, 16718, 17507, 13, 51487],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 20,
#    'seek': 2764,
#    'start': 51.72,
#    'end': 53.16,
#    'text': ' 다 됐네 소독이.',
#    'tokens': [51568, 4279, 3534, 2998, 5626, 13062, 19079, 1129, 13, 51640],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 21,
#    'seek': 2764,
#    'start': 53.44,
#    'end': 55.0,
#    'text': ' 이제 괜찮아.',
#    'tokens': [51654, 8424, 45058, 13, 51732],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 22,
#    'seek': 2764,
#    'start': 55.0,
#    'end': 56.16,
#    'text': ' 걱정 마.',
#    'tokens': [51732, 45315, 6437, 13, 51790],
#    'temperature': 0.0,
#    'avg_logprob': -0.8195759582519532,
#    'compression_ratio': 1.4625,
#    'no_speech_prob': 0.00023423650418408215},
#   {'id': 23,
#    'seek': 5616,
#    'start': 57.12,
#    'end': 59.339999999999996,
#    'text': ' 왜 여기로 와 슈퍼 가주면서.',
#    'tokens': [50412,
#     9883,
#     5518,
#     27860,
#     12500,
#     6955,
#     230,
#     41982,
#     4147,
#     21163,
#     9332,
#     13,
#     50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 24,
#    'seek': 5616,
#    'start': 59.339999999999996,
#    'end': 61.419999999999995,
#    'text': ' 아 궁금하잖아.',
#    'tokens': [50523, 2216, 32886, 2240, 17065, 13, 50627],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 25,
#    'seek': 5616,
#    'start': 61.419999999999995,
#    'end': 64.11999999999999,
#    'text': ' 내가 진짜 궁금하잖아 처음 먹어봐.',
#    'tokens': [50627,
#     10474,
#     7106,
#     32886,
#     2240,
#     17065,
#     18736,
#     28428,
#     16808,
#     13,
#     50762],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 26,
#    'seek': 5616,
#    'start': 64.11999999999999,
#    'end': 66.28,
#    'text': ' 진짜 진짜 처음이야.',
#    'tokens': [50762, 7106, 7106, 18736, 15374, 13, 50870],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 27,
#    'seek': 5616,
#    'start': 66.75999999999999,
#    'end': 71.25999999999999,
#    'text': ' 궁금하를 처음 먹는 게 아니라 궁금한 처음 먹는 길을 처음 한 것 같은데.',
#    'tokens': [50894,
#     32886,
#     8037,
#     2429,
#     18736,
#     30616,
#     7845,
#     22948,
#     32886,
#     3049,
#     18736,
#     30616,
#     25222,
#     1638,
#     18736,
#     4815,
#     4431,
#     21864,
#     13,
#     51119],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 28,
#    'seek': 5616,
#    'start': 75.12,
#    'end': 79.82,
#    'text': ' 세상에 역시 일을 생활권 지구천 한부 당시 내.',
#    'tokens': [51312,
#     37990,
#     1517,
#     34522,
#     7682,
#     1638,
#     6439,
#     40602,
#     23605,
#     4704,
#     7675,
#     18906,
#     10737,
#     6301,
#     49559,
#     6918,
#     13,
#     51547],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 29,
#    'seek': 5616,
#    'start': 79.82,
#    'end': 82.06,
#    'text': ' 어떻게 이런 우연이 있을 수 있죠?',
#    'tokens': [51547,
#     12952,
#     8381,
#     14995,
#     11557,
#     1129,
#     18082,
#     4446,
#     34070,
#     30,
#     51659],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 30,
#    'seek': 5616,
#    'start': 83.1,
#    'end': 85.42,
#    'text': ' 뭐해 이런 우연 앞에서.',
#    'tokens': [51711, 7034, 5302, 8381, 14995, 11557, 13727, 4885, 13, 51827],
#    'temperature': 0.0,
#    'avg_logprob': -0.566468958951989,
#    'compression_ratio': 1.5982905982905984,
#    'no_speech_prob': 0.00016241494449786842},
#   {'id': 31,
#    'seek': 8616,
#    'start': 86.16,
#    'end': 88.58,
#    'text': ' 두 분 인사 안 하세요?',
#    'tokens': [50364, 11915, 15361, 9385, 5727, 4811, 3369, 7046, 30, 50485],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 32,
#    'seek': 8616,
#    'start': 88.58,
#    'end': 91.25999999999999,
#    'text': ' 우연이 마주쳐도 인사 안 하기로 해서.',
#    'tokens': [50485,
#     14995,
#     11557,
#     1129,
#     6437,
#     5836,
#     20688,
#     22983,
#     9385,
#     5727,
#     4811,
#     3369,
#     27860,
#     17705,
#     13,
#     50619],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 33,
#    'seek': 8616,
#    'start': 91.25999999999999,
#    'end': 93.25999999999999,
#    'text': ' 인사 안 하기로 했어?',
#    'tokens': [50619, 9385, 5727, 4811, 3369, 27860, 49528, 30, 50719],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 34,
#    'seek': 8616,
#    'start': 93.25999999999999,
#    'end': 94.25999999999999,
#    'text': ' 하하.',
#    'tokens': [50719, 3369, 2240, 13, 50769],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 35,
#    'seek': 8616,
#    'start': 102.25999999999999,
#    'end': 108.3,
#    'text': ' 두 사람 오늘 전체적으로 노른자와 흰자가 안 내 계란으로 해.',
#    'tokens': [51169,
#     11915,
#     12211,
#     8880,
#     6831,
#     44687,
#     4130,
#     13262,
#     10798,
#     4264,
#     7590,
#     14473,
#     108,
#     22310,
#     4811,
#     6918,
#     3352,
#     2703,
#     18781,
#     4130,
#     11683,
#     13,
#     51471],
#    'temperature': 0.0,
#    'avg_logprob': -0.6705335176908053,
#    'compression_ratio': 1.34,
#    'no_speech_prob': 7.154922786867246e-05},
#   {'id': 36,
#    'seek': 10830,
#    'start': 108.5,
#    'end': 111.78,
#    'text': ' – icy 홈‑',
#    'tokens': [50374, 1662, 42015, 5930, 230, 27392, 50538],
#    'temperature': 1.0,
#    'avg_logprob': -4.049527740478515,
#    'compression_ratio': 0.9026548672566371,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 37,
#    'seek': 10830,
#    'start': 113.58,
#    'end': 115.42,
#    'text': ' licence 당림owned?',
#    'tokens': [50628, 49047, 12047, 167, 15773, 14683, 30, 50720],
#    'temperature': 1.0,
#    'avg_logprob': -4.049527740478515,
#    'compression_ratio': 0.9026548672566371,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 38,
#    'seek': 10830,
#    'start': 118.66,
#    'end': 122.97999999999999,
#    'text': ' 콩나물이네죽이pa Class finely.',
#    'tokens': [50882,
#     10630,
#     102,
#     48768,
#     11825,
#     4250,
#     5626,
#     3354,
#     121,
#     1129,
#     4306,
#     9471,
#     31529,
#     13,
#     51098],
#    'temperature': 1.0,
#    'avg_logprob': -4.049527740478515,
#    'compression_ratio': 0.9026548672566371,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 39,
#    'seek': 10830,
#    'start': 133.32,
#    'end': 136.18,
#    'text': ' 우리 학교 되게 좋죠?',
#    'tokens': [51615, 8126, 24504, 18084, 14860, 5008, 5837, 30, 51758],
#    'temperature': 1.0,
#    'avg_logprob': -4.049527740478515,
#    'compression_ratio': 0.9026548672566371,
#    'no_speech_prob': 0.00024160205794032663},
#   {'id': 40,
#    'seek': 13830,
#    'start': 138.3,
#    'end': 142.3,
#    'text': ' 좋네.',
#    'tokens': [50364, 5008, 17507, 13, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.571526709057036,
#    'compression_ratio': 1.1680672268907564,
#    'no_speech_prob': 0.0356479175388813},
#   {'id': 41,
#    'seek': 13830,
#    'start': 142.3,
#    'end': 148.3,
#    'text': ' 되게 싫은 것들 몇 가지 있었는데요?',
#    'tokens': [50564,
#     14860,
#     33649,
#     2124,
#     4431,
#     14271,
#     23628,
#     26569,
#     15972,
#     14586,
#     30,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.571526709057036,
#    'compression_ratio': 1.1680672268907564,
#    'no_speech_prob': 0.0356479175388813},
#   {'id': 42,
#    'seek': 13830,
#    'start': 148.3,
#    'end': 158.3,
#    'text': ' 저에게 좋은 것도 있었어요.',
#    'tokens': [50864, 4841, 15989, 16460, 25942, 15972, 4213, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.571526709057036,
#    'compression_ratio': 1.1680672268907564,
#    'no_speech_prob': 0.0356479175388813},
#   {'id': 43,
#    'seek': 13830,
#    'start': 158.3,
#    'end': 166.3,
#    'text': ' 좋은 건 원래 늦게 찾아오나봐요.',
#    'tokens': [51364,
#     16460,
#     13507,
#     25169,
#     7707,
#     99,
#     1810,
#     33219,
#     26969,
#     14886,
#     16808,
#     1495,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.571526709057036,
#    'compression_ratio': 1.1680672268907564,
#    'no_speech_prob': 0.0356479175388813},
#   {'id': 44,
#    'seek': 16630,
#    'start': 166.3,
#    'end': 169.3,
#    'text': ' 아저씨처럼.',
#    'tokens': [50364, 2216, 11738, 25416, 19881, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 45,
#    'seek': 16630,
#    'start': 169.3,
#    'end': 172.3,
#    'text': ' 일찍 왔는데 몇 반인지 몰랐어.',
#    'tokens': [50514,
#     7682,
#     5786,
#     235,
#     17766,
#     4189,
#     23628,
#     16396,
#     37194,
#     24833,
#     15876,
#     3103,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 46,
#    'seek': 16630,
#    'start': 172.3,
#    'end': 178.3,
#    'text': ' 말고요.',
#    'tokens': [50664, 7058, 12364, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 47,
#    'seek': 16630,
#    'start': 178.3,
#    'end': 181.3,
#    'text': ' 덕박 덕박 덕박 덕박 덕박.',
#    'tokens': [50964,
#     5596,
#     243,
#     40903,
#     5596,
#     243,
#     40903,
#     5596,
#     243,
#     40903,
#     5596,
#     243,
#     40903,
#     5596,
#     243,
#     40903,
#     13,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 48,
#    'seek': 16630,
#    'start': 181.3,
#    'end': 184.3,
#    'text': ' 잠시만, 걱정해요.',
#    'tokens': [51114, 15825, 10426, 6478, 11, 45315, 15788, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 49,
#    'seek': 16630,
#    'start': 184.3,
#    'end': 188.3,
#    'text': ' 금방 삼촌.',
#    'tokens': [51264, 4291, 2196, 17027, 32391, 15241, 234, 13, 51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 50,
#    'seek': 16630,
#    'start': 188.3,
#    'end': 190.3,
#    'text': ' 어 왔어, 무슨 일이야?',
#    'tokens': [51464, 9076, 17766, 3103, 11, 22712, 7682, 15374, 30, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 51,
#    'seek': 16630,
#    'start': 190.3,
#    'end': 194.3,
#    'text': ' 회사에서 이상한 사람 만나가지고 마음이 다 정승하고 해서.',
#    'tokens': [51564,
#     22980,
#     5727,
#     4885,
#     20362,
#     3049,
#     12211,
#     38841,
#     19747,
#     20477,
#     1129,
#     4279,
#     4980,
#     30426,
#     7040,
#     17705,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.5679680782815685,
#    'compression_ratio': 1.3617021276595744,
#    'no_speech_prob': 0.002206820761784911},
#   {'id': 52,
#    'seek': 19430,
#    'start': 194.3,
#    'end': 198.3,
#    'text': ' 끝방 삼촌 잘 계시나 해서 한번 와 봤죠.',
#    'tokens': [50364,
#     13932,
#     27630,
#     32391,
#     15241,
#     234,
#     6644,
#     10603,
#     10426,
#     3404,
#     17705,
#     14463,
#     12500,
#     20727,
#     5837,
#     13,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 53,
#    'seek': 19430,
#    'start': 198.3,
#    'end': 200.3,
#    'text': ' 근데 끝방 삼촌.',
#    'tokens': [50564, 9907, 13932, 27630, 32391, 15241, 234, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 54,
#    'seek': 19430,
#    'start': 200.3,
#    'end': 201.3,
#    'text': ' 어?',
#    'tokens': [50664, 9076, 30, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 55,
#    'seek': 19430,
#    'start': 201.3,
#    'end': 203.3,
#    'text': ' 삼촌이면 삼촌이지.',
#    'tokens': [50714,
#     32391,
#     15241,
#     234,
#     42935,
#     32391,
#     15241,
#     234,
#     25721,
#     13,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 56,
#    'seek': 19430,
#    'start': 203.3,
#    'end': 206.3,
#    'text': ' 삼촌은 왜 끝방 삼촌이에요?',
#    'tokens': [50814,
#     32391,
#     15241,
#     234,
#     2124,
#     9883,
#     13932,
#     27630,
#     32391,
#     15241,
#     234,
#     15099,
#     30,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 57,
#    'seek': 19430,
#    'start': 206.3,
#    'end': 212.3,
#    'text': ' 그러고 보니 끝방 삼촌 언제부터 우리 집에 살았죠?',
#    'tokens': [50964,
#     14019,
#     1313,
#     6330,
#     1425,
#     13932,
#     27630,
#     32391,
#     15241,
#     234,
#     16738,
#     33893,
#     12130,
#     8126,
#     38380,
#     15482,
#     243,
#     246,
#     5837,
#     30,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 58,
#    'seek': 19430,
#    'start': 212.3,
#    'end': 215.3,
#    'text': ' 부동산 계약서 보면 알잖아.',
#    'tokens': [51264,
#     10201,
#     8309,
#     16551,
#     10603,
#     19970,
#     2393,
#     19443,
#     9457,
#     17065,
#     13,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 59,
#    'seek': 19430,
#    'start': 215.3,
#    'end': 216.3,
#    'text': ' 아.',
#    'tokens': [51414, 2216, 13, 51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 60,
#    'seek': 19430,
#    'start': 216.3,
#    'end': 218.3,
#    'text': ' 근데 왜 술 병원 두 병인가요?',
#    'tokens': [51464,
#     9907,
#     9883,
#     41986,
#     32245,
#     7573,
#     11915,
#     32245,
#     4215,
#     28517,
#     30,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 61,
#    'seek': 19430,
#    'start': 218.3,
#    'end': 221.3,
#    'text': ' 누구 왔어요?',
#    'tokens': [51564, 36385, 17766, 4213, 30, 51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.16147974559238978,
#    'compression_ratio': 1.5,
#    'no_speech_prob': 0.00021932972595095634},
#   {'id': 62,
#    'seek': 22130,
#    'start': 222.3,
#    'end': 227.3,
#    'text': ' 내가 양손에 한 벽씩 주고 맛있는 걸 선호해서.',
#    'tokens': [50414,
#     10474,
#     17723,
#     45443,
#     1517,
#     4815,
#     7307,
#     121,
#     24317,
#     45848,
#     49051,
#     14240,
#     11835,
#     14705,
#     8275,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 63,
#    'seek': 22130,
#    'start': 227.3,
#    'end': 232.3,
#    'text': ' 그럼 소파 뒤에 있는 저 발 뒤꿈치는 뭐예요?',
#    'tokens': [50664,
#     13929,
#     10614,
#     17974,
#     40856,
#     7153,
#     4841,
#     13825,
#     19798,
#     30484,
#     230,
#     47255,
#     7034,
#     10790,
#     30,
#     50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 64,
#    'seek': 22130,
#    'start': 235.3,
#    'end': 238.3,
#    'text': ' 야 이게 소파가 참 예쁘다.',
#    'tokens': [51064,
#     13450,
#     10496,
#     10614,
#     17974,
#     1453,
#     18255,
#     28424,
#     1235,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 65,
#    'seek': 22130,
#    'start': 238.3,
#    'end': 240.3,
#    'text': ' 그럼 주인이 안보기 높아.',
#    'tokens': [51214,
#     13929,
#     7757,
#     30603,
#     9658,
#     7062,
#     2401,
#     25015,
#     2230,
#     13,
#     51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 66,
#    'seek': 22130,
#    'start': 240.3,
#    'end': 241.3,
#    'text': ' 마무리가 좋아가지고.',
#    'tokens': [51314, 43797, 27116, 10805, 19747, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 67,
#    'seek': 22130,
#    'start': 241.3,
#    'end': 242.3,
#    'text': ' 어?',
#    'tokens': [51364, 9076, 30, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 68,
#    'seek': 22130,
#    'start': 242.3,
#    'end': 245.3,
#    'text': ' 아까 그 이상한 그 시안한.',
#    'tokens': [51414,
#     25289,
#     4296,
#     20362,
#     3049,
#     4296,
#     5710,
#     11264,
#     3049,
#     13,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 69,
#    'seek': 22130,
#    'start': 245.3,
#    'end': 247.3,
#    'text': ' 머리 하셨네요?',
#    'tokens': [51564, 27089, 3369, 44861, 12974, 30, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 70,
#    'seek': 22130,
#    'start': 247.3,
#    'end': 248.3,
#    'text': ' 머리가 잘 됐다구나.',
#    'tokens': [51664, 27089, 1453, 6644, 16718, 1235, 23816, 13, 51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 71,
#    'seek': 22130,
#    'start': 248.3,
#    'end': 250.3,
#    'text': ' 나는 저자의 친구 이 집에 놀러.',
#    'tokens': [51714,
#     17955,
#     4841,
#     4264,
#     2785,
#     28307,
#     2620,
#     38380,
#     29873,
#     6235,
#     13,
#     51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.2846544925297532,
#    'compression_ratio': 1.407114624505929,
#    'no_speech_prob': 0.00036701795761473477},
#   {'id': 72,
#    'seek': 25030,
#    'start': 250.3,
#    'end': 251.3,
#    'text': ' 갈 거야.',
#    'tokens': [50364, 23616, 15928, 13, 50414],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 73,
#    'seek': 25030,
#    'start': 251.3,
#    'end': 253.3,
#    'text': ' 갈려던 참이었어.',
#    'tokens': [50414, 1777, 2196, 19479, 8092, 18255, 25569, 3103, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 74,
#    'seek': 25030,
#    'start': 253.3,
#    'end': 255.3,
#    'text': ' 즐거웠어.',
#    'tokens': [50514, 35177, 4285, 36450, 3103, 13, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 75,
#    'seek': 25030,
#    'start': 255.3,
#    'end': 256.3,
#    'text': ' 가.',
#    'tokens': [50614, 4147, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 76,
#    'seek': 25030,
#    'start': 256.3,
#    'end': 258.3,
#    'text': ' 어.',
#    'tokens': [50664, 9076, 13, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 77,
#    'seek': 25030,
#    'start': 258.3,
#    'end': 259.3,
#    'text': ' 그래.',
#    'tokens': [50764, 7080, 13, 50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 78,
#    'seek': 25030,
#    'start': 259.3,
#    'end': 260.3,
#    'text': ' 가.',
#    'tokens': [50814, 4147, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 79,
#    'seek': 25030,
#    'start': 260.3,
#    'end': 263.3,
#    'text': ' 만한사 방금 왔네.',
#    'tokens': [50864,
#     14671,
#     3049,
#     5727,
#     10006,
#     4781,
#     4186,
#     3261,
#     5626,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 80,
#    'seek': 25030,
#    'start': 263.3,
#    'end': 266.3,
#    'text': ' 상스러운 옷을 입었군.',
#    'tokens': [51014,
#     8563,
#     12969,
#     40537,
#     30880,
#     1638,
#     10051,
#     5642,
#     24707,
#     13,
#     51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 81,
#    'seek': 25030,
#    'start': 266.3,
#    'end': 267.3,
#    'text': ' 뭐지?',
#    'tokens': [51164, 7034, 1831, 30, 51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 82,
#    'seek': 25030,
#    'start': 267.3,
#    'end': 272.3,
#    'text': ' 출시생의 비밀에 끝방 삼촌도 한 벩가?',
#    'tokens': [51214,
#     25420,
#     3833,
#     10175,
#     2785,
#     24241,
#     108,
#     222,
#     1517,
#     13932,
#     27630,
#     32391,
#     15241,
#     234,
#     3744,
#     4815,
#     7307,
#     102,
#     1453,
#     30,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 83,
#    'seek': 25030,
#    'start': 274.3,
#    'end': 277.3,
#    'text': ' 방금 이 팀에서 뭔 소리 안 났어요?',
#    'tokens': [51564,
#     10006,
#     4781,
#     2620,
#     31448,
#     4885,
#     43972,
#     21652,
#     4811,
#     2079,
#     105,
#     4213,
#     30,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 84,
#    'seek': 25030,
#    'start': 277.3,
#    'end': 278.3,
#    'text': ' 안 났는데.',
#    'tokens': [51714, 4811, 2079, 105, 4189, 13, 51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 85,
#    'seek': 25030,
#    'start': 278.3,
#    'end': 279.3,
#    'text': ' 나는데?',
#    'tokens': [51764, 3948, 4189, 30, 51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.32185015762061403,
#    'compression_ratio': 1.2920792079207921,
#    'no_speech_prob': 0.00013779159053228796},
#   {'id': 86,
#    'seek': 27930,
#    'start': 279.3,
#    'end': 280.3,
#    'text': ' 낯수예요?',
#    'tokens': [50364, 2079, 107, 8449, 10790, 30, 50414],
#    'temperature': 0.0,
#    'avg_logprob': -0.5580294682429388,
#    'compression_ratio': 0.9157894736842105,
#    'no_speech_prob': 3.0089346182649024e-05},
#   {'id': 87,
#    'seek': 27930,
#    'start': 280.3,
#    'end': 281.3,
#    'text': ' 낯수.',
#    'tokens': [50414, 2079, 107, 8449, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.5580294682429388,
#    'compression_ratio': 0.9157894736842105,
#    'no_speech_prob': 3.0089346182649024e-05},
#   {'id': 88,
#    'seek': 27930,
#    'start': 281.3,
#    'end': 282.3,
#    'text': ' 덕후야.',
#    'tokens': [50464, 5596, 243, 26799, 4248, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5580294682429388,
#    'compression_ratio': 0.9157894736842105,
#    'no_speech_prob': 3.0089346182649024e-05},
#   {'id': 89,
#    'seek': 27930,
#    'start': 288.3,
#    'end': 290.3,
#    'text': ' 나 5초론만 동갑게.',
#    'tokens': [50814,
#     3948,
#     1025,
#     15241,
#     2196,
#     94,
#     4673,
#     6478,
#     11685,
#     27358,
#     1810,
#     13,
#     50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.5580294682429388,
#    'compression_ratio': 0.9157894736842105,
#    'no_speech_prob': 3.0089346182649024e-05},
#   {'id': 90,
#    'seek': 27930,
#    'start': 303.3,
#    'end': 305.3,
#    'text': ' 문 닭구간!',
#    'tokens': [51564, 13086, 2515, 255, 7675, 5989, 0, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5580294682429388,
#    'compression_ratio': 0.9157894736842105,
#    'no_speech_prob': 3.0089346182649024e-05},
#   {'id': 91,
#    'seek': 27930,
#    'start': 305.3,
#    'end': 307.3,
#    'text': ' 투명붙여.',
#    'tokens': [51664, 1175, 48458, 8792, 167, 114, 247, 10558, 13, 51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.5580294682429388,
#    'compression_ratio': 0.9157894736842105,
#    'no_speech_prob': 3.0089346182649024e-05},
#   {'id': 92,
#    'seek': 30930,
#    'start': 310.3,
#    'end': 312.3,
#    'text': ' 나 말 한만.',
#    'tokens': [50414, 3948, 7058, 10737, 6478, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 93,
#    'seek': 30930,
#    'start': 312.3,
#    'end': 313.3,
#    'text': ' 색사기.',
#    'tokens': [50514, 22530, 5727, 2401, 13, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 94,
#    'seek': 30930,
#    'start': 323.3,
#    'end': 326.3,
#    'text': ' 아니 왜 이 애쓰는 그런지가 언제인데 웃이라노.',
#    'tokens': [51064,
#     5651,
#     9883,
#     2620,
#     21459,
#     49140,
#     108,
#     1098,
#     9306,
#     30232,
#     43790,
#     13481,
#     25014,
#     4250,
#     9316,
#     37524,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 95,
#    'seek': 30930,
#    'start': 328.3,
#    'end': 329.3,
#    'text': ' 나 10만 한만.',
#    'tokens': [51314, 3948, 1266, 5978, 10737, 6478, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 96,
#    'seek': 30930,
#    'start': 329.3,
#    'end': 330.3,
#    'text': ' 고기사기.',
#    'tokens': [51364, 9161, 2401, 5727, 2401, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 97,
#    'seek': 30930,
#    'start': 332.3,
#    'end': 333.3,
#    'text': ' 야.',
#    'tokens': [51514, 13450, 13, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 98,
#    'seek': 30930,
#    'start': 333.3,
#    'end': 337.3,
#    'text': ' 널 내 기억에 그대로 둔 신혜 뜻이 있겠지.',
#    'tokens': [51564,
#     3214,
#     238,
#     6918,
#     30935,
#     1517,
#     41711,
#     8108,
#     242,
#     13042,
#     5262,
#     250,
#     44774,
#     1129,
#     2297,
#     5137,
#     1831,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.4691728403870489,
#    'compression_ratio': 1.2171052631578947,
#    'no_speech_prob': 6.453731475630775e-05},
#   {'id': 99,
#    'seek': 33730,
#    'start': 338.3,
#    'end': 340.3,
#    'text': ' 그렇게까지 얘기하지 못해서 골라놔고.',
#    'tokens': [50414,
#     16104,
#     8786,
#     19641,
#     16175,
#     10239,
#     8275,
#     42142,
#     9316,
#     228,
#     242,
#     1313,
#     13,
#     50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 100,
#    'seek': 33730,
#    'start': 340.3,
#    'end': 342.3,
#    'text': ' 마지막 방금 벌써는 수박해.',
#    'tokens': [50514,
#     22722,
#     10006,
#     4781,
#     49175,
#     1098,
#     22297,
#     21697,
#     5302,
#     13,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 101,
#    'seek': 33730,
#    'start': 342.3,
#    'end': 346.3,
#    'text': ' 옛날 생각해서 금방 알아 뚝딱 안 된다.',
#    'tokens': [50614,
#     48646,
#     8594,
#     8275,
#     4291,
#     2196,
#     17027,
#     32352,
#     39181,
#     251,
#     39147,
#     109,
#     4811,
#     16975,
#     1235,
#     13,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 102,
#    'seek': 33730,
#    'start': 346.3,
#    'end': 349.3,
#    'text': ' 고유 번호 있어서 내가 나 팔지도 못한다고.',
#    'tokens': [50814,
#     9161,
#     19062,
#     10212,
#     14705,
#     27937,
#     10474,
#     3948,
#     37110,
#     39871,
#     10239,
#     3049,
#     7726,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 103,
#    'seek': 33730,
#    'start': 350.3,
#    'end': 352.3,
#    'text': ' 골라 저럭군.',
#    'tokens': [51014, 42142, 2742, 13163, 253, 255, 24707, 13, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 104,
#    'seek': 33730,
#    'start': 354.3,
#    'end': 356.3,
#    'text': ' 소개팅하기만 해 아주.',
#    'tokens': [51214, 42784, 27086, 2240, 7091, 6478, 11683, 22360, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 105,
#    'seek': 33730,
#    'start': 356.3,
#    'end': 358.3,
#    'text': ' 거의 6분이 한 대 무슨.',
#    'tokens': [51314, 27872, 1386, 15937, 1129, 4815, 5971, 22712, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 106,
#    'seek': 33730,
#    'start': 361.3,
#    'end': 364.3,
#    'text': ' 6분이 오라고 했다.',
#    'tokens': [51564, 1386, 15937, 1129, 10258, 6954, 8154, 1235, 13, 51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 107,
#    'seek': 33730,
#    'start': 364.3,
#    'end': 366.3,
#    'text': ' 어디 사나요?',
#    'tokens': [51714, 20879, 6606, 26057, 30, 51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.5151070159615823,
#    'compression_ratio': 1.3526970954356847,
#    'no_speech_prob': 0.0012786185834556818},
#   {'id': 108,
#    'seek': 36730,
#    'start': 368.3,
#    'end': 369.3,
#    'text': ' 저 스타일 아니시라니까.',
#    'tokens': [50414, 4841, 45881, 5651, 10426, 2742, 5690, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 109,
#    'seek': 36730,
#    'start': 369.3,
#    'end': 371.3,
#    'text': ' 인튀고 적상해준 맛재료?',
#    'tokens': [50464,
#     9385,
#     5963,
#     222,
#     1313,
#     14370,
#     5979,
#     44487,
#     222,
#     9508,
#     1574,
#     1698,
#     21305,
#     30,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 110,
#    'seek': 36730,
#    'start': 371.3,
#    'end': 373.3,
#    'text': ' 어떻게 내 동의도 없어요?',
#    'tokens': [50564, 12952, 6918, 11685, 673, 8226, 31162, 30, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 111,
#    'seek': 36730,
#    'start': 373.3,
#    'end': 375.3,
#    'text': ' 어떻게 여기저기다 다 커밍이 나왔을래요?',
#    'tokens': [50664,
#     12952,
#     7543,
#     11738,
#     2401,
#     1235,
#     4279,
#     39573,
#     108,
#     235,
#     1129,
#     26374,
#     1638,
#     167,
#     4241,
#     1495,
#     30,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 112,
#    'seek': 36730,
#    'start': 375.3,
#    'end': 376.3,
#    'text': ' 앞에 봐.',
#    'tokens': [50764, 42004, 15507, 13, 50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 113,
#    'seek': 36730,
#    'start': 376.3,
#    'end': 377.3,
#    'text': ' 왼쪽으로 다시 찾아.',
#    'tokens': [50814, 4186, 120, 16094, 4130, 15463, 33219, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 114,
#    'seek': 36730,
#    'start': 379.3,
#    'end': 380.3,
#    'text': ' 왜 불하네요?',
#    'tokens': [50964, 9883, 16285, 8037, 12974, 30, 51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 115,
#    'seek': 36730,
#    'start': 380.3,
#    'end': 384.3,
#    'text': ' 아니 너 운전하는 거 보니까 진짜 어른된 것 같아.',
#    'tokens': [51014,
#     5651,
#     12963,
#     4709,
#     47595,
#     7116,
#     3675,
#     25612,
#     7106,
#     4863,
#     98,
#     1397,
#     14987,
#     4431,
#     23396,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 116,
#    'seek': 36730,
#    'start': 384.3,
#    'end': 385.3,
#    'text': ' 차선 차선.',
#    'tokens': [51214, 15391, 12421, 15391, 12421, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 117,
#    'seek': 36730,
#    'start': 385.3,
#    'end': 386.3,
#    'text': ' 핸들 꽉 쫑.',
#    'tokens': [51264, 1362, 1397, 2403, 24378, 231, 37453, 239, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 118,
#    'seek': 36730,
#    'start': 386.3,
#    'end': 387.3,
#    'text': ' 아 나 보고 있어.',
#    'tokens': [51314, 2216, 3948, 18942, 17300, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 119,
#    'seek': 36730,
#    'start': 387.3,
#    'end': 388.3,
#    'text': ' 아니지.',
#    'tokens': [51364, 5651, 1831, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 120,
#    'seek': 36730,
#    'start': 388.3,
#    'end': 389.3,
#    'text': ' 다 알지.',
#    'tokens': [51414, 4279, 9457, 1831, 13, 51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 121,
#    'seek': 36730,
#    'start': 389.3,
#    'end': 390.3,
#    'text': ' 내가 신기했어.',
#    'tokens': [51464, 10474, 47958, 36756, 13, 51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 122,
#    'seek': 36730,
#    'start': 390.3,
#    'end': 391.3,
#    'text': ' 그래.',
#    'tokens': [51514, 7080, 13, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 123,
#    'seek': 36730,
#    'start': 391.3,
#    'end': 392.3,
#    'text': ' 좋습니다.',
#    'tokens': [51564, 5008, 3115, 13, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 124,
#    'seek': 36730,
#    'start': 392.3,
#    'end': 393.3,
#    'text': ' 처음 타봐서.',
#    'tokens': [51614, 18736, 8675, 2366, 16808, 2393, 13, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 125,
#    'seek': 36730,
#    'start': 394.3,
#    'end': 395.3,
#    'text': ' 좀 좋아해 줘.',
#    'tokens': [51714, 6796, 10805, 5302, 41926, 13, 51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.5163909716483874,
#    'compression_ratio': 1.450657894736842,
#    'no_speech_prob': 0.0008191171800717711},
#   {'id': 126,
#    'seek': 39530,
#    'start': 395.3,
#    'end': 398.3,
#    'text': ' 저의 전 왼쪽 왼쪽.',
#    'tokens': [50364,
#     4841,
#     2785,
#     6831,
#     4186,
#     120,
#     16094,
#     4186,
#     120,
#     16094,
#     13,
#     50514],
#    'temperature': 0.2,
#    'avg_logprob': -0.4790010710020323,
#    'compression_ratio': 1.1818181818181819,
#    'no_speech_prob': 0.0034696138463914394},
#   {'id': 127,
#    'seek': 39530,
#    'start': 400.3,
#    'end': 401.3,
#    'text': ' 아 진짜.',
#    'tokens': [50614, 2216, 7106, 13, 50664],
#    'temperature': 0.2,
#    'avg_logprob': -0.4790010710020323,
#    'compression_ratio': 1.1818181818181819,
#    'no_speech_prob': 0.0034696138463914394},
#   {'id': 128,
#    'seek': 39530,
#    'start': 401.3,
#    'end': 403.3,
#    'text': ' 어디 가는데요?',
#    'tokens': [50664, 20879, 4147, 14586, 30, 50764],
#    'temperature': 0.2,
#    'avg_logprob': -0.4790010710020323,
#    'compression_ratio': 1.1818181818181819,
#    'no_speech_prob': 0.0034696138463914394},
#   {'id': 129,
#    'seek': 39530,
#    'start': 404.3,
#    'end': 406.3,
#    'text': ' 그 좌회전인데 깜빡이 키라고 깜빡이 항상.',
#    'tokens': [50814,
#     4296,
#     3340,
#     234,
#     15048,
#     8210,
#     13481,
#     8394,
#     2163,
#     117,
#     94,
#     1129,
#     21959,
#     2990,
#     6954,
#     8394,
#     2163,
#     117,
#     94,
#     1129,
#     30747,
#     13,
#     50914],
#    'temperature': 0.2,
#    'avg_logprob': -0.4790010710020323,
#    'compression_ratio': 1.1818181818181819,
#    'no_speech_prob': 0.0034696138463914394},
#   {'id': 130,
#    'seek': 39530,
#    'start': 412.3,
#    'end': 414.3,
#    'text': ' 산패연에 7도에서 구도사회가 딱이지.',
#    'tokens': [51214,
#     29589,
#     7827,
#     101,
#     11557,
#     1517,
#     1614,
#     3744,
#     4885,
#     17386,
#     1838,
#     5727,
#     15048,
#     1453,
#     16681,
#     25721,
#     13,
#     51314],
#    'temperature': 0.2,
#    'avg_logprob': -0.4790010710020323,
#    'compression_ratio': 1.1818181818181819,
#    'no_speech_prob': 0.0034696138463914394},
#   {'id': 131,
#    'seek': 39530,
#    'start': 419.3,
#    'end': 420.3,
#    'text': ' 그 빨갛자.',
#    'tokens': [51564, 4296, 46954, 1126, 249, 4264, 13, 51614],
#    'temperature': 0.2,
#    'avg_logprob': -0.4790010710020323,
#    'compression_ratio': 1.1818181818181819,
#    'no_speech_prob': 0.0034696138463914394},
#   {'id': 132,
#    'seek': 42030,
#    'start': 420.3,
#    'end': 423.3,
#    'text': ' 아 왜 안 마셔도 치하는 거 같네 나는.',
#    'tokens': [50364,
#     2216,
#     9883,
#     4811,
#     6437,
#     6961,
#     40720,
#     18447,
#     7116,
#     3675,
#     4385,
#     17507,
#     17955,
#     13,
#     50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5066027390329462,
#    'compression_ratio': 1.1654676258992807,
#    'no_speech_prob': 7.447557436535135e-05},
#   {'id': 133,
#    'seek': 42030,
#    'start': 423.3,
#    'end': 426.3,
#    'text': ' 벌써 치하면 어떻게 해.',
#    'tokens': [50514, 49175, 18447, 16283, 12952, 11683, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5066027390329462,
#    'compression_ratio': 1.1654676258992807,
#    'no_speech_prob': 7.447557436535135e-05},
#   {'id': 134,
#    'seek': 42030,
#    'start': 438.3,
#    'end': 439.3,
#    'text': ' 어이씨.',
#    'tokens': [51264, 9076, 3946, 242, 101, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.5066027390329462,
#    'compression_ratio': 1.1654676258992807,
#    'no_speech_prob': 7.447557436535135e-05},
#   {'id': 135,
#    'seek': 42030,
#    'start': 439.3,
#    'end': 441.3,
#    'text': ' 3쪽까지 왜 이래.',
#    'tokens': [51314, 805, 16094, 8786, 9883, 2892, 4241, 13, 51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.5066027390329462,
#    'compression_ratio': 1.1654676258992807,
#    'no_speech_prob': 7.447557436535135e-05},
#   {'id': 136,
#    'seek': 42030,
#    'start': 443.3,
#    'end': 445.3,
#    'text': ' 괜찮으세요?',
#    'tokens': [51514, 18286, 10307, 7046, 30, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.5066027390329462,
#    'compression_ratio': 1.1654676258992807,
#    'no_speech_prob': 7.447557436535135e-05},
#   {'id': 137,
#    'seek': 42030,
#    'start': 445.3,
#    'end': 446.3,
#    'text': ' 안 색이 안 좋으세요.',
#    'tokens': [51614, 4811, 22530, 1129, 4811, 5008, 10307, 7046, 13, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5066027390329462,
#    'compression_ratio': 1.1654676258992807,
#    'no_speech_prob': 7.447557436535135e-05},
#   {'id': 138,
#    'seek': 44630,
#    'start': 446.3,
#    'end': 447.3,
#    'text': ' 괜찮으세요?',
#    'tokens': [50364, 18286, 10307, 7046, 30, 50414],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 139,
#    'seek': 44630,
#    'start': 447.3,
#    'end': 449.3,
#    'text': ' 안 색이 안 좋으세요.',
#    'tokens': [50414, 4811, 22530, 1129, 4811, 5008, 10307, 7046, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 140,
#    'seek': 44630,
#    'start': 449.3,
#    'end': 450.3,
#    'text': ' 괜찮지?',
#    'tokens': [50514, 18286, 1831, 30, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 141,
#    'seek': 44630,
#    'start': 450.3,
#    'end': 451.3,
#    'text': ' 오케이.',
#    'tokens': [50564, 30567, 13, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 142,
#    'seek': 44630,
#    'start': 452.3,
#    'end': 453.3,
#    'text': ' 집도 얼마 추웠어.',
#    'tokens': [50664, 12111, 3744, 44859, 17435, 36450, 3103, 13, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 143,
#    'seek': 44630,
#    'start': 454.3,
#    'end': 455.3,
#    'text': ' 한잔 하시겠어요?',
#    'tokens': [50764, 4815, 48267, 3369, 3833, 30826, 30, 50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 144,
#    'seek': 44630,
#    'start': 456.3,
#    'end': 457.3,
#    'text': ' 네.',
#    'tokens': [50864, 8808, 13, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 145,
#    'seek': 44630,
#    'start': 457.3,
#    'end': 458.3,
#    'text': ' 저 지금 뭐.',
#    'tokens': [50914, 4841, 7356, 7034, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 146,
#    'seek': 44630,
#    'start': 460.3,
#    'end': 461.3,
#    'text': ' 김대표님.',
#    'tokens': [51064, 43629, 3638, 18923, 9466, 13, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 147,
#    'seek': 44630,
#    'start': 461.3,
#    'end': 462.3,
#    'text': ' 김대표님.',
#    'tokens': [51114, 43629, 3638, 18923, 9466, 13, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 148,
#    'seek': 44630,
#    'start': 462.3,
#    'end': 464.3,
#    'text': ' 아 진짜 저심들 좀 하자.',
#    'tokens': [51164,
#     2216,
#     7106,
#     4841,
#     1995,
#     1698,
#     2403,
#     6796,
#     3369,
#     4264,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 149,
#    'seek': 44630,
#    'start': 464.3,
#    'end': 467.3,
#    'text': ' 3손 들 너무 굳이해하고 천진 난만 해.',
#    'tokens': [51264,
#     805,
#     45443,
#     6275,
#     6924,
#     4946,
#     111,
#     1129,
#     5302,
#     7040,
#     31076,
#     8097,
#     2079,
#     2163,
#     6478,
#     11683,
#     13,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 150,
#    'seek': 44630,
#    'start': 471.3,
#    'end': 472.3,
#    'text': ' 뭐지?',
#    'tokens': [51614, 7034, 1831, 30, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 151,
#    'seek': 44630,
#    'start': 472.3,
#    'end': 473.3,
#    'text': ' 왜 이머리 입에 짝 붙지?',
#    'tokens': [51664,
#     9883,
#     2892,
#     101,
#     14981,
#     10051,
#     1517,
#     2334,
#     251,
#     24618,
#     1831,
#     30,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.37592108496304216,
#    'compression_ratio': 1.355140186915888,
#    'no_speech_prob': 0.00018848308536689728},
#   {'id': 152,
#    'seek': 47330,
#    'start': 474.3,
#    'end': 476.3,
#    'text': ' 너.',
#    'tokens': [50414, 12963, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.7192373275756836,
#    'compression_ratio': 1.0260869565217392,
#    'no_speech_prob': 0.0056146057322621346},
#   {'id': 153,
#    'seek': 47330,
#    'start': 482.3,
#    'end': 484.3,
#    'text': ' 아 왜 안 해요 무슨 노래.',
#    'tokens': [50814, 2216, 9883, 4811, 25744, 22712, 24678, 13, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.7192373275756836,
#    'compression_ratio': 1.0260869565217392,
#    'no_speech_prob': 0.0056146057322621346},
#   {'id': 154,
#    'seek': 47330,
#    'start': 484.3,
#    'end': 489.3,
#    'text': ' 왜 이렇게 많은 사람들 가운데',
#    'tokens': [50914, 9883, 5483, 5671, 2124, 39570, 44627, 51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.7192373275756836,
#    'compression_ratio': 1.0260869565217392,
#    'no_speech_prob': 0.0056146057322621346},
#   {'id': 155,
#    'seek': 47330,
#    'start': 490.3,
#    'end': 496.3,
#    'text': ' 너를 만난 건 정말의 운이야.',
#    'tokens': [51214,
#     3214,
#     31567,
#     8165,
#     16662,
#     13507,
#     12793,
#     2785,
#     4709,
#     112,
#     15374,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.7192373275756836,
#    'compression_ratio': 1.0260869565217392,
#    'no_speech_prob': 0.0056146057322621346},
#   {'id': 156,
#    'seek': 49630,
#    'start': 497.3,
#    'end': 502.3,
#    'text': ' 이렇게 넓은 새 사랑 가운데.',
#    'tokens': [50414, 5483, 3214, 241, 2124, 31184, 22581, 44627, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.4136404489216052,
#    'compression_ratio': 1.1304347826086956,
#    'no_speech_prob': 0.17705269157886505},
#   {'id': 157,
#    'seek': 49630,
#    'start': 502.3,
#    'end': 504.3,
#    'text': ' 다같이.',
#    'tokens': [50664, 4279, 22226, 1129, 13, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.4136404489216052,
#    'compression_ratio': 1.1304347826086956,
#    'no_speech_prob': 0.17705269157886505},
#   {'id': 158,
#    'seek': 49630,
#    'start': 504.3,
#    'end': 509.3,
#    'text': ' 그들 만난 건 나 역시 기쁨이야.',
#    'tokens': [50764,
#     2003,
#     2403,
#     8165,
#     16662,
#     13507,
#     3948,
#     34522,
#     7047,
#     15404,
#     101,
#     15374,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.4136404489216052,
#    'compression_ratio': 1.1304347826086956,
#    'no_speech_prob': 0.17705269157886505},
#   {'id': 159,
#    'seek': 49630,
#    'start': 511.3,
#    'end': 516.3,
#    'text': ' 이렇게 많은 사람들 가운데.',
#    'tokens': [51114, 5483, 18494, 39570, 44627, 13, 51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.4136404489216052,
#    'compression_ratio': 1.1304347826086956,
#    'no_speech_prob': 0.17705269157886505}],
#  'language': 'ko'}

# %%
transcript = result['text']
transcript
# Out:
# ' 300살이면 한창 아프고 그럴 때지. 괜찮아. 왜? 다시 사실 하나. 답을 어떻게 위해선 답과 가까운 자에게 다가가야 한다. 뭔 소리야? 야 무슨 짓이야 이게 너 하나야. 역시 너에게 나무것도 보이지 않는군. 그저 따뜻할 때. 아 깜짝짝 아파 아파. 야 대소 어떻게 할 거야? 너 꼭 잘 먹었어. 대소. 이소 어떻게 할 거야? 이소. 아 더워. 더워 더워. 잘라버려야 돼. 소독. 이런면 됐죠? 됐네. 다 됐네 소독이. 이제 괜찮아. 걱정 마. 왜 여기로 와 슈퍼 가주면서. 아 궁금하잖아. 내가 진짜 궁금하잖아 처음 먹어봐. 진짜 진짜 처음이야. 궁금하를 처음 먹는 게 아니라 궁금한 처음 먹는 길을 처음 한 것 같은데. 세상에 역시 일을 생활권 지구천 한부 당시 내. 어떻게 이런 우연이 있을 수 있죠? 뭐해 이런 우연 앞에서. 두 분 인사 안 하세요? 우연이 마주쳐도 인사 안 하기로 해서. 인사 안 하기로 했어? 하하. 두 사람 오늘 전체적으로 노른자와 흰자가 안 내 계란으로 해. – icy 홈‑ licence 당림owned? 콩나물이네죽이pa Class finely. 우리 학교 되게 좋죠? 좋네. 되게 싫은 것들 몇 가지 있었는데요? 저에게 좋은 것도 있었어요. 좋은 건 원래 늦게 찾아오나봐요. 아저씨처럼. 일찍 왔는데 몇 반인지 몰랐어. 말고요. 덕박 덕박 덕박 덕박 덕박. 잠시만, 걱정해요. 금방 삼촌. 어 왔어, 무슨 일이야? 회사에서 이상한 사람 만나가지고 마음이 다 정승하고 해서. 끝방 삼촌 잘 계시나 해서 한번 와 봤죠. 근데 끝방 삼촌. 어? 삼촌이면 삼촌이지. 삼촌은 왜 끝방 삼촌이에요? 그러고 보니 끝방 삼촌 언제부터 우리 집에 살았죠? 부동산 계약서 보면 알잖아. 아. 근데 왜 술 병원 두 병인가요? 누구 왔어요? 내가 양손에 한 벽씩 주고 맛있는 걸 선호해서. 그럼 소파 뒤에 있는 저 발 뒤꿈치는 뭐예요? 야 이게 소파가 참 예쁘다. 그럼 주인이 안보기 높아. 마무리가 좋아가지고. 어? 아까 그 이상한 그 시안한. 머리 하셨네요? 머리가 잘 됐다구나. 나는 저자의 친구 이 집에 놀러. 갈 거야. 갈려던 참이었어. 즐거웠어. 가. 어. 그래. 가. 만한사 방금 왔네. 상스러운 옷을 입었군. 뭐지? 출시생의 비밀에 끝방 삼촌도 한 벩가? 방금 이 팀에서 뭔 소리 안 났어요? 안 났는데. 나는데? 낯수예요? 낯수. 덕후야. 나 5초론만 동갑게. 문 닭구간! 투명붙여. 나 말 한만. 색사기. 아니 왜 이 애쓰는 그런지가 언제인데 웃이라노. 나 10만 한만. 고기사기. 야. 널 내 기억에 그대로 둔 신혜 뜻이 있겠지. 그렇게까지 얘기하지 못해서 골라놔고. 마지막 방금 벌써는 수박해. 옛날 생각해서 금방 알아 뚝딱 안 된다. 고유 번호 있어서 내가 나 팔지도 못한다고. 골라 저럭군. 소개팅하기만 해 아주. 거의 6분이 한 대 무슨. 6분이 오라고 했다. 어디 사나요? 저 스타일 아니시라니까. 인튀고 적상해준 맛재료? 어떻게 내 동의도 없어요? 어떻게 여기저기다 다 커밍이 나왔을래요? 앞에 봐. 왼쪽으로 다시 찾아. 왜 불하네요? 아니 너 운전하는 거 보니까 진짜 어른된 것 같아. 차선 차선. 핸들 꽉 쫑. 아 나 보고 있어. 아니지. 다 알지. 내가 신기했어. 그래. 좋습니다. 처음 타봐서. 좀 좋아해 줘. 저의 전 왼쪽 왼쪽. 아 진짜. 어디 가는데요? 그 좌회전인데 깜빡이 키라고 깜빡이 항상. 산패연에 7도에서 구도사회가 딱이지. 그 빨갛자. 아 왜 안 마셔도 치하는 거 같네 나는. 벌써 치하면 어떻게 해. 어이씨. 3쪽까지 왜 이래. 괜찮으세요? 안 색이 안 좋으세요. 괜찮으세요? 안 색이 안 좋으세요. 괜찮지? 오케이. 집도 얼마 추웠어. 한잔 하시겠어요? 네. 저 지금 뭐. 김대표님. 김대표님. 아 진짜 저심들 좀 하자. 3손 들 너무 굳이해하고 천진 난만 해. 뭐지? 왜 이머리 입에 짝 붙지? 너. 아 왜 안 해요 무슨 노래. 왜 이렇게 많은 사람들 가운데 너를 만난 건 정말의 운이야. 이렇게 넓은 새 사랑 가운데. 다같이. 그들 만난 건 나 역시 기쁨이야. 이렇게 많은 사람들 가운데.'

# %%
matches = search_text(transcript, target_text)
matches
# Out:
# extract_audio processing...
# [(11, 20)]

# %%
time_matches = map_time(result, matches)
time_matches
# Out:
# mapping time processing...
# [(10.06, 20.98)]

# %%
print_results(time_matches)
# Out:
# 대사 발견: 10.06초 - 20.98초
